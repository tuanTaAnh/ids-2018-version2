# %%
import pandas as pd
import tensorflow as tf
import numpy as np
import torch
import torch.nn as nn
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset, DataLoader

# %%
# torch.cuda.is_available() checks and returns a Boolean True if a GPU is available, else it'll return False
is_cuda = torch.cuda.is_available()

# If we have a GPU available, we'll set our device to GPU. We'll use this device variable later in our code.
if is_cuda:
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

# %%
path = r"/Users/taanhtuan/Desktop/workproject/ids-2018-detection/02-15-2018.csv"

# %%
df = pd.read_csv(path)

# %%
df.head()
# Out:
#    Dst Port  Protocol            Timestamp  Flow Duration  Tot Fwd Pkts  \
# 0         0         0  15/02/2018 08:25:18      112641158             3
# 1        22         6  15/02/2018 08:29:05       37366762            14
# 2     47514         6  15/02/2018 08:29:42            543             2
# 3         0         0  15/02/2018 08:28:07      112640703             3
# 4         0         0  15/02/2018 08:30:56      112640874             3
#
#    Tot Bwd Pkts  TotLen Fwd Pkts  TotLen Bwd Pkts  Fwd Pkt Len Max  \
# 0             0                0                0                0
# 1            12             2168             2993              712
# 2             0               64                0               64
# 3             0                0                0                0
# 4             0                0                0                0
#
#    Fwd Pkt Len Min  ...  Fwd Seg Size Min  Active Mean     Active Std  \
# 0                0  ...                 0          0.0       0.000000
# 1                0  ...                32    1024353.0  649038.754495
# 2                0  ...                32          0.0       0.000000
# 3                0  ...                 0          0.0       0.000000
# 4                0  ...                 0          0.0       0.000000
#
#    Active Max  Active Min   Idle Mean      Idle Std  Idle Max  Idle Min  \
# 0           0           0  56320579.0  7.042784e+02  56321077  56320081
# 1     1601183      321569  11431221.0  3.644991e+06  15617415   8960247
# 2           0           0         0.0  0.000000e+00         0         0
# 3           0           0  56320351.5  3.669884e+02  56320611  56320092
# 4           0           0  56320437.0  7.198347e+02  56320946  56319928
#
#     Label
# 0  Benign
# 1  Benign
# 2  Benign
# 3  Benign
# 4  Benign
#
# [5 rows x 80 columns]

# %%
for col in df.columns:
    print(col, ": ", df.iloc[0][col])
# Out:
# Dst Port :  0
# Protocol :  0
# Timestamp :  15/02/2018 08:25:18
# Flow Duration :  112641158
# Tot Fwd Pkts :  3
# Tot Bwd Pkts :  0
# TotLen Fwd Pkts :  0
# TotLen Bwd Pkts :  0
# Fwd Pkt Len Max :  0
# Fwd Pkt Len Min :  0
# Fwd Pkt Len Mean :  0.0
# Fwd Pkt Len Std :  0.0
# Bwd Pkt Len Max :  0
# Bwd Pkt Len Min :  0
# Bwd Pkt Len Mean :  0.0
# Bwd Pkt Len Std :  0.0
# Flow Byts/s :  0.0
# Flow Pkts/s :  0.0266332489
# Flow IAT Mean :  56320579.0
# Flow IAT Std :  704.2783540618
# Flow IAT Max :  56321077
# Flow IAT Min :  56320081
# Fwd IAT Tot :  112641158
# Fwd IAT Mean :  56320579.0
# Fwd IAT Std :  704.2783540618
# Fwd IAT Max :  56321077
# Fwd IAT Min :  56320081
# Bwd IAT Tot :  0
# Bwd IAT Mean :  0.0
# Bwd IAT Std :  0.0
# Bwd IAT Max :  0
# Bwd IAT Min :  0
# Fwd PSH Flags :  0
# Bwd PSH Flags :  0
# Fwd URG Flags :  0
# Bwd URG Flags :  0
# Fwd Header Len :  0
# Bwd Header Len :  0
# Fwd Pkts/s :  0.0266332489
# Bwd Pkts/s :  0.0
# Pkt Len Min :  0
# Pkt Len Max :  0
# Pkt Len Mean :  0.0
# Pkt Len Std :  0.0
# Pkt Len Var :  0.0
# FIN Flag Cnt :  0
# SYN Flag Cnt :  0
# RST Flag Cnt :  0
# PSH Flag Cnt :  0
# ACK Flag Cnt :  0
# URG Flag Cnt :  0
# CWE Flag Count :  0
# ECE Flag Cnt :  0
# Down/Up Ratio :  0
# Pkt Size Avg :  0.0
# Fwd Seg Size Avg :  0.0
# Bwd Seg Size Avg :  0.0
# Fwd Byts/b Avg :  0
# Fwd Pkts/b Avg :  0
# Fwd Blk Rate Avg :  0
# Bwd Byts/b Avg :  0
# Bwd Pkts/b Avg :  0
# Bwd Blk Rate Avg :  0
# Subflow Fwd Pkts :  3
# Subflow Fwd Byts :  0
# Subflow Bwd Pkts :  0
# Subflow Bwd Byts :  0
# Init Fwd Win Byts :  -1
# Init Bwd Win Byts :  -1
# Fwd Act Data Pkts :  0
# Fwd Seg Size Min :  0
# Active Mean :  0.0
# Active Std :  0.0
# Active Max :  0
# Active Min :  0
# Idle Mean :  56320579.0
# Idle Std :  704.2783540618
# Idle Max :  56321077
# Idle Min :  56320081
# Label :  Benign

# %%
num_of_samples = len(df)
unique_values = df["Dst Port"].value_counts()
unique_values = unique_values.reset_index()
for value in unique_values.iterrows():
#     percentage = float((value[1]["Dst Port"]*100/num_of_samples))
#     if percentage > 0.01:
#         print("the percentage of ", value[1]['index'], " occupied", percentage)
# print("and some values with trivial percentage")
    print("the number of ", value[1]['index'], " is", value[1]["Dst Port"])
# Out:
# the number of  53  is 333090
# the number of  80  is 239043
# the number of  443  is 155851
# the number of  3389  is 74961
# the number of  445  is 57168
# the number of  0  is 18565
# the number of  3128  is 11989
# the number of  5355  is 6899
# the number of  137  is 2798
# the number of  67  is 1025
# the number of  138  is 668
# the number of  30303  is 661
# the number of  139  is 529
# the number of  22  is 458
# the number of  123  is 391
# the number of  23  is 280
# the number of  49154  is 146
# the number of  1900  is 104
# the number of  50071  is 56
# the number of  49896  is 54
# the number of  49825  is 54
# the number of  49733  is 53
# the number of  50188  is 52
# the number of  49729  is 51
# the number of  50113  is 50
# the number of  50023  is 50
# the number of  50060  is 50
# the number of  50024  is 50
# the number of  50077  is 49
# the number of  50111  is 49
# the number of  50254  is 49
# the number of  50154  is 49
# the number of  49866  is 49
# the number of  49497  is 49
# the number of  49775  is 49
# the number of  49891  is 49
# the number of  49737  is 49
# the number of  50251  is 48
# the number of  50108  is 48
# the number of  50045  is 48
# the number of  49881  is 48
# the number of  50055  is 48
# the number of  50380  is 48
# the number of  50074  is 47
# the number of  49734  is 47
# the number of  50878  is 47
# the number of  49923  is 47
# the number of  50801  is 47
# the number of  50334  is 47
# the number of  49732  is 47
# the number of  49774  is 47
# the number of  49776  is 47
# the number of  50273  is 47
# the number of  50112  is 47
# the number of  6800  is 47
# the number of  50237  is 47
# the number of  49879  is 47
# the number of  50087  is 46
# the number of  50333  is 46
# the number of  3478  is 46
# the number of  50922  is 46
# the number of  49777  is 46
# the number of  49738  is 46
# the number of  49892  is 46
# the number of  50983  is 43
# the number of  49710  is 43
# the number of  50090  is 43
# the number of  49994  is 43
# the number of  50083  is 43
# the number of  49535  is 43
# the number of  50981  is 43
# the number of  49828  is 43
# the number of  50329  is 43
# the number of  50007  is 43
# the number of  49901  is 43
# the number of  49494  is 43
# the number of  49877  is 43
# the number of  50064  is 43
# the number of  50189  is 43
# the number of  50057  is 43
# the number of  50272  is 43
# the number of  49781  is 43
# the number of  50070  is 43
# the number of  50625  is 43
# the number of  50138  is 43
# the number of  49827  is 43
# the number of  50638  is 43
# the number of  49749  is 43
# the number of  50131  is 43
# the number of  50073  is 43
# the number of  50618  is 43
# the number of  50001  is 43
# the number of  49850  is 43
# the number of  50450  is 42
# the number of  50451  is 42
# the number of  50054  is 42
# the number of  49830  is 42
# the number of  50799  is 42
# the number of  50203  is 42
# the number of  49845  is 42
# the number of  50204  is 42
# the number of  49784  is 42
# the number of  51010  is 42
# the number of  50044  is 42
# the number of  50528  is 42
# the number of  50502  is 42
# the number of  50828  is 42
# the number of  51053  is 42
# the number of  50339  is 42
# the number of  49848  is 42
# the number of  49995  is 42
# the number of  49764  is 42
# the number of  49873  is 42
# the number of  50208  is 42
# the number of  49999  is 42
# the number of  49931  is 42
# the number of  50277  is 42
# the number of  50282  is 42
# the number of  50019  is 42
# the number of  49807  is 42
# the number of  50918  is 42
# the number of  49902  is 42
# the number of  50576  is 42
# the number of  50039  is 42
# the number of  50242  is 42
# the number of  51206  is 42
# the number of  49832  is 42
# the number of  51084  is 42
# the number of  49757  is 42
# the number of  50025  is 42
# the number of  49707  is 42
# the number of  50153  is 42
# the number of  49730  is 42
# the number of  50294  is 42
# the number of  50305  is 42
# the number of  49834  is 42
# the number of  49506  is 42
# the number of  50069  is 42
# the number of  49763  is 42
# the number of  49772  is 42
# the number of  50180  is 42
# the number of  49884  is 42
# the number of  50361  is 42
# the number of  50465  is 42
# the number of  49724  is 42
# the number of  50881  is 42
# the number of  50617  is 42
# the number of  49790  is 42
# the number of  50235  is 42
# the number of  49791  is 42
# the number of  49788  is 42
# the number of  50094  is 42
# the number of  49912  is 42
# the number of  49789  is 42
# the number of  50371  is 42
# the number of  50352  is 42
# the number of  50880  is 42
# the number of  50146  is 42
# the number of  50976  is 42
# the number of  50250  is 41
# the number of  50944  is 41
# the number of  50161  is 41
# the number of  50608  is 41
# the number of  50022  is 41
# the number of  50105  is 41
# the number of  50134  is 41
# the number of  50793  is 41
# the number of  50336  is 41
# the number of  50830  is 41
# the number of  50445  is 41
# the number of  50917  is 41
# the number of  49863  is 41
# the number of  50822  is 41
# the number of  49661  is 41
# the number of  50190  is 41
# the number of  50499  is 41
# the number of  51098  is 41
# the number of  50335  is 41
# the number of  50417  is 41
# the number of  50476  is 41
# the number of  51369  is 41
# the number of  50482  is 41
# the number of  50014  is 41
# the number of  50015  is 41
# the number of  50000  is 41
# the number of  50376  is 41
# the number of  49953  is 41
# the number of  50513  is 41
# the number of  49846  is 41
# the number of  49897  is 41
# the number of  50805  is 41
# the number of  49819  is 41
# the number of  50827  is 41
# the number of  50577  is 41
# the number of  49818  is 41
# the number of  49849  is 41
# the number of  49804  is 41
# the number of  50436  is 41
# the number of  50246  is 41
# the number of  51099  is 41
# the number of  50387  is 41
# the number of  50075  is 41
# the number of  50456  is 41
# the number of  50283  is 41
# the number of  49916  is 41
# the number of  50600  is 41
# the number of  50080  is 41
# the number of  49744  is 41
# the number of  49755  is 41
# the number of  50710  is 41
# the number of  50779  is 41
# the number of  50616  is 41
# the number of  49756  is 41
# the number of  50257  is 41
# the number of  50537  is 41
# the number of  50199  is 41
# the number of  49813  is 41
# the number of  49512  is 41
# the number of  50046  is 41
# the number of  50463  is 41
# the number of  50442  is 41
# the number of  50711  is 41
# the number of  49796  is 41
# the number of  50037  is 41
# the number of  50115  is 41
# the number of  49520  is 41
# the number of  50103  is 41
# the number of  49745  is 41
# the number of  50440  is 41
# the number of  50700  is 41
# the number of  50088  is 41
# the number of  49880  is 41
# the number of  50628  is 41
# the number of  50099  is 41
# the number of  51052  is 41
# the number of  49760  is 41
# the number of  49840  is 41
# the number of  51027  is 40
# the number of  50478  is 40
# the number of  50963  is 40
# the number of  50580  is 40
# the number of  50379  is 40
# the number of  50205  is 40
# the number of  49492  is 40
# the number of  49759  is 40
# the number of  50004  is 40
# the number of  49498  is 40
# the number of  50578  is 40
# the number of  50477  is 40
# the number of  49761  is 40
# the number of  49909  is 40
# the number of  49910  is 40
# the number of  49952  is 40
# the number of  51371  is 40
# the number of  50314  is 40
# the number of  50292  is 40
# the number of  50013  is 40
# the number of  50524  is 40
# the number of  49977  is 40
# the number of  49833  is 40
# the number of  50555  is 40
# the number of  50568  is 40
# the number of  50152  is 40
# the number of  50086  is 40
# the number of  50487  is 40
# the number of  49464  is 40
# the number of  49489  is 40
# the number of  50426  is 40
# the number of  50035  is 40
# the number of  50114  is 40
# the number of  50838  is 40
# the number of  50998  is 40
# the number of  50496  is 40
# the number of  50041  is 40
# the number of  50509  is 40
# the number of  50644  is 40
# the number of  50048  is 40
# the number of  50863  is 40
# the number of  50916  is 40
# the number of  49487  is 40
# the number of  51751  is 40
# the number of  49947  is 40
# the number of  49991  is 40
# the number of  49921  is 40
# the number of  50970  is 40
# the number of  50474  is 40
# the number of  49765  is 40
# the number of  50530  is 40
# the number of  49478  is 40
# the number of  49826  is 40
# the number of  50171  is 40
# the number of  49930  is 40
# the number of  50712  is 40
# the number of  51364  is 40
# the number of  49890  is 40
# the number of  50148  is 40
# the number of  50505  is 40
# the number of  49811  is 40
# the number of  49950  is 40
# the number of  50591  is 40
# the number of  50079  is 40
# the number of  50043  is 40
# the number of  50589  is 40
# the number of  50178  is 40
# the number of  50129  is 40
# the number of  49713  is 40
# the number of  50641  is 40
# the number of  50350  is 40
# the number of  50639  is 40
# the number of  50820  is 40
# the number of  50811  is 40
# the number of  50642  is 40
# the number of  49773  is 40
# the number of  50401  is 40
# the number of  50126  is 40
# the number of  50370  is 40
# the number of  50553  is 40
# the number of  50149  is 40
# the number of  49521  is 40
# the number of  50984  is 38
# the number of  50033  is 38
# the number of  49888  is 38
# the number of  49709  is 38
# the number of  50369  is 38
# the number of  50839  is 38
# the number of  49482  is 38
# the number of  49532  is 38
# the number of  50047  is 38
# the number of  50388  is 38
# the number of  50192  is 38
# the number of  51384  is 38
# the number of  49924  is 38
# the number of  50470  is 38
# the number of  50517  is 38
# the number of  50141  is 38
# the number of  50143  is 38
# the number of  49823  is 38
# the number of  50036  is 38
# the number of  50962  is 38
# the number of  50904  is 38
# the number of  50640  is 38
# the number of  51090  is 38
# the number of  50032  is 38
# the number of  50949  is 38
# the number of  50140  is 38
# the number of  51372  is 38
# the number of  50873  is 38
# the number of  49728  is 38
# the number of  50065  is 38
# the number of  50542  is 38
# the number of  50252  is 38
# the number of  50965  is 38
# the number of  50198  is 38
# the number of  50636  is 38
# the number of  50834  is 38
# the number of  51123  is 38
# the number of  50444  is 38
# the number of  50196  is 38
# the number of  51761  is 38
# the number of  49870  is 38
# the number of  50647  is 38
# the number of  49895  is 38
# the number of  49517  is 38
# the number of  50979  is 38
# the number of  50632  is 38
# the number of  50831  is 38
# the number of  50398  is 38
# the number of  50919  is 38
# the number of  49505  is 38
# the number of  50320  is 38
# the number of  49956  is 38
# the number of  49792  is 38
# the number of  49988  is 38
# the number of  50795  is 38
# the number of  49945  is 38
# the number of  50397  is 38
# the number of  49751  is 38
# the number of  50634  is 38
# the number of  51043  is 38
# the number of  49933  is 38
# the number of  50095  is 38
# the number of  50646  is 38
# the number of  50454  is 38
# the number of  49949  is 38
# the number of  51292  is 38
# the number of  50280  is 38
# the number of  50791  is 38
# the number of  50433  is 38
# the number of  50341  is 38
# the number of  50699  is 38
# the number of  50026  is 38
# the number of  49529  is 38
# the number of  49797  is 38
# the number of  51632  is 38
# the number of  50637  is 38
# the number of  50959  is 38
# the number of  49486  is 38
# the number of  50823  is 38
# the number of  50987  is 38
# the number of  50176  is 38
# the number of  50133  is 38
# the number of  51078  is 38
# the number of  49766  is 38
# the number of  50824  is 38
# the number of  50318  is 38
# the number of  51275  is 38
# the number of  49984  is 38
# the number of  50802  is 38
# the number of  50672  is 38
# the number of  50658  is 38
# the number of  49536  is 38
# the number of  51039  is 38
# the number of  51095  is 38
# the number of  49802  is 38
# the number of  49856  is 38
# the number of  50234  is 38
# the number of  50604  is 38
# the number of  50422  is 38
# the number of  49857  is 38
# the number of  49468  is 38
# the number of  50244  is 38
# the number of  51035  is 38
# the number of  49803  is 38
# the number of  49801  is 38
# the number of  50109  is 38
# the number of  50378  is 38
# the number of  50574  is 38
# the number of  50620  is 38
# the number of  50993  is 38
# the number of  51368  is 38
# the number of  49779  is 38
# the number of  51673  is 38
# the number of  50605  is 38
# the number of  50488  is 37
# the number of  50974  is 37
# the number of  50697  is 37
# the number of  50848  is 37
# the number of  50249  is 37
# the number of  49652  is 37
# the number of  51295  is 37
# the number of  49985  is 37
# the number of  50299  is 37
# the number of  50810  is 37
# the number of  50325  is 37
# the number of  50742  is 37
# the number of  49808  is 37
fwd Pkt Len Min  ...  Fwd Seg Size Min  Active Mean  Active Std  \
# 0                      0  ...                 0          0.0         0.0
# 996214                 0  ...                 0          0.0         0.0
# 291427                 0  ...                 0          0.0         0.0
# 291441                 0  ...                 0          0.0         0.0
# 641582                 0  ...                 0          0.0         0.0
# ...                  ...  ...               ...          ...         ...
# 51050                  0  ...                20          0.0         0.0
# 794475                 0  ...                20          0.0         0.0
# 538984                 0  ...                20          0.0         0.0
# 1001464                0  ...                20          0.0         0.0
# 410749                 0  ...                20          0.0         0.0
#
#          Active Max  Active Min     Idle Mean      Idle Std  Idle Max  \
# 0                 0           0  5.632058e+07  7.042784e+02  56321077
# 996214            0           0  5.631995e+07  2.687006e+01  56319966
# 291427            0           0  3.426601e+07  6.768126e+06  42071428
# 291441            0           0  0.000000e+00  0.000000e+00         0
# 641582            0           0  0.000000e+00  0.000000e+00         0
# ...             ...         ...           ...           ...       ...
# 51050             0           0  0.000000e+00  0.000000e+00         0
# 794475            0           0  0.000000e+00  0.000000e+00         0
# 538984            0           0  0.000000e+00  0.000000e+00         0
# 1001464           0           0  0.000000e+00  0.000000e+00         0
# 410749            0           0  0.000000e+00  0.000000e+00         0
#
#          Idle Min   Label
# 0        56320081  Benign
# 996214   56319928  Benign
# 291427   30025543  Benign
# 291441          0  Benign
# 641582          0  Benign
# ...           ...     ...
# 51050           0  Benign
# 794475          0  Benign
# 538984          0  Benign
# 1001464         0  Benign
# 410749          0  Benign
#
# [1048575 rows x 80 columns]

# %%
dropped_columns = ["Timestamp"]
df = df.drop(dropped_columns, axis=1)

# %%
X = df.iloc[:, df.columns != 'Label']
Y = df.iloc[:, df.columns == 'Label']

# %%
Y = df.iloc[:, df.columns == 'Label']
unique_values = Y["Label"].value_counts()
print(unique_values)
# Out:
# Benign                   996077
# DoS attacks-GoldenEye     41508
# DoS attacks-Slowloris     10990
# Name: Label, dtype: int64

# %%
ord_enc = OrdinalEncoder()
Y = ord_enc.fit_transform(Y)

# %%
Y = Y.ravel()

# %%
Y.shape
# Out:
# (1048575,)

# %%
X
# Out:
#          Dst Port  Protocol  Flow Duration  Tot Fwd Pkts  Tot Bwd Pkts  \
# 0               0         0      112641158             3             0
# 1              22         6       37366762            14            12
# 2           47514         6            543             2             0
# 3               0         0      112640703             3             0
# 4               0         0      112640874             3             0
# ...           ...       ...            ...           ...           ...
# 1048570     50111         6             22             3             0
# 1048571       443         6       54682783             5             1
# 1048572       443         6       53682093             5             1
# 1048573       443         6       54683364             5             1
# 1048574       443         6      116857161            18            17
#
#          TotLen Fwd Pkts  TotLen Bwd Pkts  Fwd Pkt Len Max  Fwd Pkt Len Min  \
# 0                      0                0                0                0
# 1                   2168             2993              712                0
# 2                     64                0               64                0
# 3                      0                0                0                0
# 4                      0                0                0                0
# ...                  ...              ...              ...              ...
# 1048570               31                0               31                0
# 1048571              123               46               46                0
# 1048572              123               46               46                0
# 1048573              123               46               46                0
# 1048574             1066             5265              281                0
#
#          Fwd Pkt Len Mean  ...  Fwd Act Data Pkts  Fwd Seg Size Min  \
# 0                0.000000  ...                  0                 0
# 1              154.857143  ...                  8                32
# 2               32.000000  ...                  0                32
# 3                0.000000  ...                  0                 0
# 4                0.000000  ...                  0                 0
# ...                   ...  ...                ...               ...
# 1048570         10.333333  ...                  1                20
# 1048571         24.600000  ...                  2                20
# 1048572         24.600000  ...                  2                20
# 1048573         24.600000  ...                  2                20
# 1048574         59.222222  ...                  8                20
#
#          Active Mean     Active Std  Active Max  Active Min   Idle Mean  \
# 0                0.0       0.000000           0           0  56320579.0
# 1          1024353.0  649038.754495     1601183      321569  11431221.0
# 2                0.0       0.000000           0           0         0.0
# 3                0.0       0.000000           0           0  56320351.5
# 4                0.0       0.000000           0           0  56320437.0
# ...              ...            ...         ...         ...         ...
# 1048570          0.0       0.000000           0           0         0.0
# 1048571     158783.0       0.000000      158783      158783  54523813.0
# 1048572     259719.0       0.000000      259719      259719  53421756.0
# 1048573     158870.0       0.000000      158870      158870  54523593.0
# 1048574     221407.0   48231.753545      255512      187302  58082282.0
#
#              Idle Std  Idle Max  Idle Min
# 0        7.042784e+02  56321077  56320081
# 1        3.644991e+06  15617415   8960247
# 2        0.000000e+00         0         0
# 3        3.669884e+02  56320611  56320092
# 4        7.198347e+02  56320946  56319928
# ...               ...       ...       ...
# 1048570  0.000000e+00         0         0
# 1048571  0.000000e+00  54523813  54523813
# 1048572  0.000000e+00  53421756  53421756
# 1048573  0.000000e+00  54523593  54523593
# 1048574  1.832213e+05  58211839  57952725
#
# [1048575 rows x 78 columns]

# %%
heig = len(X.columns)
Dst_list = []
X_uniq_vals = X["Dst Port"].value_counts()
X_uniq_vals = X_uniq_vals.reset_index()

leng = X_uniq_vals.iloc[0]['Dst Port']

print("leng: ", leng)
print("heig: ", heig)
# Out:
# leng:  333090
# heig:  78

# %%
inputs = np.zeros((1500000,100,78))
num_of_inputs = 0

his_record = 100
num_of_feat = 78
    
for value in X_uniq_vals.iterrows():
    print("value index: ", value[1]['index'])
    
    mask = X['Dst Port'] == value[1]['index']
    dfX = X[mask].to_numpy()
    print(type(dfX))
    dfX = dfX.transpose()
    
    extra_df = np.zeros((num_of_feat, his_record))
    count = 0;
    
    new_df = np.concatenate((extra_df, dfX), axis=1)
    new_df = new_df.transpose()
    
    df_leng = new_df.shape[0]
    
    print(extra_df.shape)
    print(dfX.shape)
    print(new_df.shape)
    print(new_df[0].shape)
    print(df_leng)
    
    for i in range(his_record,df_leng):
        print("num_of_inputs: ", num_of_inputs)
        inputs[num_of_inputs] = new_df[i-his_record:i][:]
        num_of_inputs += 1
        if(num_of_inputs == 10000):
            break;

    if value[1]['index'] == 53:
        break;
#         arr = torch.from_numpy(arr).float()
# Out:
# value index:  53
# <class 'numpy.ndarray'>
# (78, 100)
# (78, 333090)
# (333190, 78)
# (78,)
# 333190
# num_of_inputs:  0
# num_of_inputs:  1
# num_of_inputs:  2
# num_of_inputs:  3
# num_of_inputs:  4
# num_of_inputs:  5
# num_of_inputs:  6
# num_of_inputs:  7
# num_of_inputs:  8
# num_of_inputs:  9
# num_of_inputs:  10
# num_of_inputs:  11
# num_of_inputs:  12
# num_of_inputs:  13
# num_of_inputs:  14
# num_of_inputs:  15
# num_of_inputs:  16
# num_of_inputs:  17
# num_of_inputs:  18
# num_of_inputs:  19
# num_of_inputs:  20
# num_of_inputs:  21
# num_of_inputs:  22
# num_of_inputs:  23
# num_of_inputs:  24
# num_of_inputs:  25
# num_of_inputs:  26
# num_of_inputs:  27
# num_of_inputs:  28
# num_of_inputs:  29
# num_of_inputs:  30
# num_of_inputs:  31
# num_of_inputs:  32
# num_of_inputs:  33
# num_of_inputs:  34
# num_of_inputs:  35
# num_of_inputs:  36
# num_of_inputs:  37
# num_of_inputs:  38
# num_of_inputs:  39
# num_of_inputs:  40
# num_of_inputs:  41
# num_of_inputs:  42
# num_of_inputs:  43
# num_of_inputs:  44
# num_of_inputs:  45
# num_of_inputs:  46
# num_of_inputs:  47
# num_of_inputs:  48
# num_of_inputs:  49
# num_of_inputs:  50
# num_of_inputs:  51
# num_of_inputs:  52
# num_of_inputs:  53
# num_of_inputs:  54
# num_of_inputs:  55
# num_of_inputs:  56
# num_of_inputs:  57
# num_of_inputs:  58
# num_of_inputs:  59
# num_of_inputs:  60
# num_of_inputs:  61
# num_of_inputs:  62
# num_of_inputs:  63
# num_of_inputs:  64
# num_of_inputs:  65
# num_of_inputs:  66
# num_of_inputs:  67
# num_of_inputs:  68
# num_of_inputs:  69
# num_of_inputs:  70
# num_of_inputs:  71
# num_of_inputs:  72
# num_of_inputs:  73
# num_of_inputs:  74
# num_of_inputs:  75
# num_of_inputs:  76
# num_of_inputs:  77
# num_of_inputs:  78
# num_of_inputs:  79
# num_of_inputs:  80
# num_of_inputs:  81
# num_of_inputs:  82
# num_of_inputs:  83
# num_of_inputs:  84
# num_of_inputs:  85
# num_of_inputs:  86
# num_of_inputs:  87
# num_of_inputs:  88
# num_of_inputs:  89
# num_of_inputs:  90
# num_of_inputs:  91
# num_of_inputs:  92
# num_of_inputs:  93
# num_of_inputs:  94
# num_of_inputs:  95
# num_of_inputs:  96
# num_of_inputs:  97
# num_of_inputs:  98
# num_of_inputs:  99
# num_of_inputs:  100
# num_of_inputs:  101
# num_of_inputs:  102
# num_of_inputs:  103
# num_of_inputs:  104
# num_of_inputs:  105
# num_of_inputs:  106
# num_of_inputs:  107
# num_of_inputs:  108
# num_of_inputs:  109
# num_of_inputs:  110
# num_of_inputs:  111
# num_of_inputs:  112
# num_of_inputs:  113
# num_of_inputs:  114
# num_of_inputs:  115
# num_of_inputs:  116
# num_of_inputs:  117
# num_of_inputs:  118
# num_of_inputs:  119
# num_of_inputs:  120
# num_of_inputs:  121
# num_of_inputs:  122
# num_of_inputs:  123
# num_of_inputs:  124
# num_of_inputs:  125
# num_of_inputs:  126
# num_of_inputs:  127
# num_of_inputs:  128
# num_of_inputs:  129
# num_of_inputs:  130
# num_of_inputs:  131
# num_of_inputs:  132
# num_of_inputs:  133
# num_of_inputs:  134
# num_of_inputs:  135
# num_of_inputs:  136
# num_of_inputs:  137
# num_of_inputs:  138
# num_of_inputs:  139
# num_of_inputs:  140
# num_of_inputs:  141
# num_of_inputs:  142
# num_of_inputs:  143
# num_of_inputs:  144
# num_of_inputs:  145
# num_of_inputs:  146
# num_of_inputs:  147
# num_of_inputs:  148
# num_of_inputs:  149
# num_of_inputs:  150
# num_of_inputs:  151
# num_of_inputs:  152
# num_of_inputs:  153
# num_of_inputs:  154
# num_of_inputs:  155
# num_of_inputs:  156
# num_of_inputs:  157
# num_of_inputs:  158
# num_of_inputs:  159
# num_of_inputs:  160
# num_of_inputs:  161
# num_of_inputs:  162
# num_of_inputs:  163
# num_of_inputs:  164
# num_of_inputs:  165
# num_of_inputs:  166
# num_of_inputs:  167
# num_of_inputs:  168
# num_of_inputs:  169
# num_of_inputs:  170
# num_of_inputs:  171
# num_of_inputs:  172
# num_of_inputs:  173
# num_of_inputs:  174
# num_of_inputs:  175
# num_of_inputs:  176
# num_of_inputs:  177
# num_of_inputs:  178
# num_of_inputs:  179
# num_of_inputs:  180
# num_of_inputs:  181
# num_of_inputs:  182
# num_of_inputs:  183
# num_of_inputs:  184
# num_of_inputs:  185
# num_of_inputs:  186
# num_of_inputs:  187
# num_of_inputs:  188
# num_of_inputs:  189
# num_of_inputs:  190
# num_of_inputs:  191
# num_of_inputs:  192
# num_of_inputs:  193
# num_of_inputs:  194
# num_of_inputs:  195
# num_of_inputs:  196
# num_of_inputs:  197
# num_of_inputs:  198
# num_of_inputs:  199
# num_of_inputs:  200
# num_of_inputs:  201
# num_of_inputs:  202
# num_of_inputs:  203
# num_of_inputs:  204
# num_of_inputs:  205
# num_of_inputs:  206
# num_of_inputs:  207
# num_of_inputs:  208
# num_of_inputs:  209
# num_of_inputs:  210
# num_of_inputs:  211
# num_of_inputs:  212
# num_of_inputs:  213
# num_of_inputs:  214
# num_of_inputs:  215
# num_of_inputs:  216
# num_of_inputs:  217
# num_of_inputs:  218
# num_of_inputs:  219
# num_of_inputs:  220
# num_of_inputs:  221
# num_of_inputs:  222
# num_of_inputs:  223
# num_of_inputs:  224
# num_of_inputs:  225
# num_of_inputs:  226
# num_of_inputs:  227
# num_of_inputs:  228
# num_of_inputs:  229
# num_of_inputs:  230
# num_of_inputs:  231
# num_of_inputs:  232
# num_of_inputs:  233
# num_of_inputs:  234
# num_of_inputs:  235
# num_of_inputs:  236
# num_of_inputs:  237
# num_of_inputs:  238
# num_of_inputs:  239
# num_of_inputs:  240
# num_of_inputs:  241
# num_of_inputs:  242
# num_of_inputs:  243
# num_of_inputs:  244
# num_of_inputs:  245
# num_of_inputs:  246
# num_of_inputs:  247
# num_of_inputs:  248
# num_of_inputs:  249
# num_of_inputs:  250
# num_of_inputs:  251
# num_of_inputs:  252
# num_of_inputs:  253
# num_of_inputs:  254
# num_of_inputs:  255
# num_of_inputs:  256
# num_of_inputs:  257
# num_of_inputs:  258
# num_of_inputs:  259
# num_of_inputs:  260
# num_of_inputs:  261
# num_of_inputs:  262
# num_of_inputs:  263
# num_of_inputs:  264
# num_of_inputs:  265
# num_of_inputs:  266
# num_of_inputs:  267
# num_of_inputs:  268
# num_of_inputs:  269
# num_of_inputs:  270
# num_of_inputs:  271
# num_of_inputs:  272
# num_of_inputs:  273
# num_of_inputs:  274
# num_of_inputs:  275
# num_of_inputs:  276
# num_of_inputs:  277
# num_of_inputs:  278
# num_of_inputs:  279
# num_of_inputs:  280
# num_of_inputs:  281
# num_of_inputs:  282
# num_of_inputs:  283
# num_of_inputs:  284
# num_of_inputs:  285
# num_of_inputs:  286
# num_of_inputs:  287
# num_of_inputs:  288
# num_of_inputs:  289
# num_of_inputs:  290
# num_of_inputs:  291
# num_of_inputs:  292
# num_of_inputs:  293
# num_of_inputs:  294
# num_of_inputs:  295
# num_of_inputs:  296
# num_of_inputs:  297
# num_of_inputs:  298
# num_of_inputs:  299
# num_of_inputs:  300
# num_of_inputs:  301
# num_of_inputs:  302
# num_of_inputs:  303
# num_of_inputs:  304
# num_of_inputs:  305
# num_of_inputs:  306
# num_of_inputs:  307
# num_of_inputs:  308
# num_of_inputs:  309
# num_of_inputs:  310
# num_of_inputs:  311
# num_of_inputs:  312
# num_of_inputs:  313
# num_of_inputs:  314
# num_of_inputs:  315
# num_of_inputs:  316
# num_of_inputs:  317
# num_of_inputs:  318
# num_of_inputs:  319
# num_of_inputs:  320
# num_of_inputs:  321
# num_of_inputs:  322
# num_of_inputs:  323
# num_of_inputs:  324
# num_of_inputs:  325
# num_of_inputs:  326
# num_of_inputs:  327
# num_of_inputs:  328
# num_of_inputs:  329
# num_of_inputs:  330
# num_of_inputs:  331
# num_of_inputs:  332
# num_of_inputs:  333
# num_of_inputs:  334
# num_of_inputs:  335
# num_of_inputs:  336
# num_of_inputs:  337
# num_of_inputs:  338
# num_of_inputs:  339
# num_of_inputs:  340
# num_of_inputs:  341
# num_of_inputs:  342
# num_of_inputs:  343
# num_of_inputs:  344
# num_of_inputs:  345
# num_of_inputs:  346
# num_of_inputs:  347
# num_of_inputs:  348
# num_of_inputs:  349
# num_of_inputs:  350
# num_of_inputs:  351
# num_of_inputs:  352
# num_of_inputs:  353
# num_of_inputs:  354
# num_of_inputs:  355
# num_of_inputs:  356
# num_of_inputs:  357
# num_of_inputs:  358
# num_of_inputs:  359
# num_of_inputs:  360
# num_of_inputs:  361
# num_of_inputs:  362
# num_of_inputs:  363
# num_of_inputs:  364
# num_of_inputs:  365
# num_of_inputs:  366
# num_of_inputs:  367
# num_of_inputs:  368
# num_of_inputs:  369
# num_of_inputs:  370
# num_of_inputs:  371
# num_of_inputs:  372
# num_of_inputs:  373
# num_of_inputs:  374
# num_of_inputs:  375
# num_of_inputs:  376
# num_of_inputs:  377
# num_of_inputs:  378
# num_of_inputs:  379
# num_of_inputs:  380
# num_of_inputs:  381
# num_of_inputs:  382
# num_of_inputs:  383
# num_of_inputs:  384
# num_of_inputs:  385
# num_of_inputs:  386
# num_of_inputs:  387
# num_of_inputs:  388
# num_of_inputs:  389
# num_of_inputs:  390
# num_of_inputs:  391
# num_of_inputs:  392
# num_of_inputs:  393
# num_of_inputs:  394
# num_of_inputs:  395
# num_of_inputs:  396
# num_of_inputs:  397
# num_of_inputs:  398
# num_of_inputs:  399
# num_of_inputs:  400
# num_of_inputs:  401
# num_of_inputs:  402
# num_of_inputs:  403
# num_of_inputs:  404
# num_of_inputs:  405
# num_of_inputs:  406
# num_of_inputs:  407
# num_of_inputs:  408
# num_of_inputs:  409
# num_of_inputs:  410
# num_of_inputs:  411
# num_of_inputs:  412
# num_of_inputs:  413
# num_of_inputs:  414
# num_of_inputs:  415
# num_of_inputs:  416
# num_of_inputs:  417
# num_of_inputs:  418
# num_of_inputs:  419
# num_of_inputs:  420
# num_of_inputs:  421
# num_of_inputs:  422
# num_of_inputs:  423
# num_of_inputs:  424
# num_of_inputs:  425
# num_of_inputs:  426
# num_of_inputs:  427
# num_of_inputs:  428
# num_of_inputs:  429
# num_of_inputs:  430
# num_of_inputs:  431
# num_of_inputs:  432
# num_of_inputs:  433
# num_of_inputs:  434
# num_of_inputs:  435
# num_of_inputs:  436
# num_of_inputs:  437
# num_of_inputs:  438
# num_of_inputs:  439
# num_of_inputs:  440
# num_of_inputs:  441
# num_of_inputs:  442
# num_of_inputs:  443
# num_of_inputs:  444
# num_of_inputs:  445
# num_of_inputs:  446
# num_of_inputs:  447
# num_of_inputs:  448
# num_of_inputs:  449
# num_of_inputs:  450
# num_of_inputs:  451
# num_of_inputs:  452
# num_of_inputs:  453
# num_of_inputs:  454
# num_of_inputs:  455
# num_of_inputs:  456
# num_of_inputs:  457
# num_of_inputs:  458
# num_of_inputs:  459
# num_of_inputs:  460
# num_of_inputs:  461
# num_of_inputs:  462
# num_of_inputs:  463
# num_of_inputs:  464
# num_of_inputs:  465
# num_of_inputs:  466
# num_of_inputs:  467
# num_of_inputs:  468
# num_of_inputs:  469
# num_of_inputs:  470
# num_of_inputs:  471
# num_of_inputs:  472
# num_of_inputs:  473
# num_of_inputs:  474
# num_of_inputs:  475
# num_of_inputs:  476
# num_of_inputs:  477
# num_of_inputs:  478
# num_of_inputs:  479
# num_of_inputs:  480
# num_of_inputs:  481
# num_of_inputs:  482
# num_of_inputs:  483
# num_of_inputs:  484
# num_of_inputs:  485
# num_of_inputs:  486
# num_of_inputs:  487
# num_of_inputs:  488
# num_of_inputs:  489
# num_of_inputs:  490
# num_of_inputs:  491
# num_of_inputs:  492
# num_of_inputs:  493
# num_of_inputs:  494
# num_of_inputs:  495
# num_of_inputs:  496
# num_of_inputs:  497
# num_of_inputs:  498
# num_of_inputs:  499
# num_of_inputs:  500
# num_of_inputs:  501
# num_of_inputs:  502
# num_of_inputs:  503
# num_of_inputs:  504
# num_of_inputs:  505
# num_of_inputs:  506
# num_of_inputs:  507
# num_of_inputs:  508
# num_of_inputs:  509
# num_of_inputs:  510
# num_of_inputs:  511
# num_of_inputs:  512
# num_of_inputs:  513
# num_of_inputs:  514
# num_of_inputs:  515
# num_of_inputs:  516
# num_of_inputs:  517
# num_of_inputs:  518
# num_of_inputs:  519
# num_of_inputs:  520
# num_of_inputs:  521
# num_of_inputs:  522
# num_of_inputs:  523
# num_of_inputs:  524
# num_of_inputs:  525
# num_of_inputs:  526
# num_of_inputs:  527
# num_of_inputs:  528
# num_of_inputs:  529
# num_of_inputs:  530
# num_of_inputs:  531
# num_of_inputs:  532
# num_of_inputs:  533
# num_of_inputs:  534
# num_of_inputs:  535
# num_of_inputs:  536
# num_of_inputs:  537
# num_of_inputs:  538
# num_of_inputs:  539
# num_of_inputs:  540
# num_of_inputs:  541
# num_of_inputs:  542
# num_of_inputs:  543
# num_of_inputs:  544
# num_of_inputs:  545
# num_of_inputs:  546
# num_of_inputs:  547
# num_of_inputs:  548
# num_of_inputs:  549
# num_of_inputs:  550
# num_of_inputs:  551
# num_of_inputs:  552
# num_of_inputs:  553
# num_of_inputs:  554
# num_of_inputs:  555
# num_of_inputs:  556
# num_of_inputs:  557
# num_of_inputs:  558
# num_of_inputs:  559
# num_of_inputs:  560
# num_of_inputs:  561
# num_of_inputs:  562
# num_of_inputs:  563
# num_of_inputs:  564
# num_of_inputs:  565
# num_of_inputs:  566
# num_of_inputs:  567
# num_of_inputs:  568
# num_of_inputs:  569
# num_of_inputs:  570
# num_of_inputs:  571
# num_of_inputs:  572
# num_of_inputs:  573
# num_of_inputs:  574
# num_of_inputs:  575
# num_of_inputs:  576
# num_of_inputs:  577
# num_of_inputs:  578
# num_of_inputs:  579
# num_of_inputs:  580
# num_of_inputs:  581
# num_of_inputs:  582
# num_of_inputs:  583
# num_of_inputs:  584
# num_of_inputs:  585
# num_of_inputs:  586
# num_of_inputs:  587
# num_of_inputs:  588
# num_of_inputs:  589
# num_of_inputs:  590
# num_of_inputs:  591
# num_of_inputs:  592
# num_of_inputs:  593
# num_of_inputs:  594
# num_of_inputs:  595
# num_of_inputs:  596
# num_of_inputs:  597
# num_of_inputs:  598
# num_of_inputs:  599
# num_of_inputs:  600
# num_of_inputs:  601
# num_of_inputs:  602
# num_of_inputs:  603
# num_of_inputs:  604
# num_of_inputs:  605
# num_of_inputs:  606
# num_of_inputs:  607
# num_of_inputs:  608
# num_of_inputs:  609
# num_of_inputs:  610
# num_of_inputs:  611
# num_of_inputs:  612
# num_of_inputs:  613
# num_of_inputs:  614
# num_of_inputs:  615
# num_of_inputs:  616
# num_of_inputs:  617
# num_of_inputs:  618
# num_of_inputs:  619
# num_of_inputs:  620
# num_of_inputs:  621
# num_of_inputs:  622
# num_of_inputs:  623
# num_of_inputs:  624
# num_of_inputs:  625
# num_of_inputs:  626
# num_of_inputs:  627
# num_of_inputs:  628
# num_of_inputs:  629
# num_of_inputs:  630
# num_of_inputs:  631
# num_of_inputs:  632
# num_of_inputs:  633
# num_of_inputs:  634
# num_of_inputs:  635
# num_of_inputs:  636
# num_of_inputs:  637
# num_of_inputs:  638
# num_of_inputs:  639
# num_of_inputs:  640
# num_of_inputs:  641
# num_of_inputs:  642
# num_of_inputs:  643
# num_of_inputs:  644
# num_of_inputs:  645
# num_of_inputs:  646
# num_of_inputs:  647
# num_of_inputs:  648
# num_of_inputs:  649
# num_of_inputs:  650
# num_of_inputs:  651
# num_of_inputs:  652
# num_of_inputs:  653
# num_of_inputs:  654
# num_of_inputs:  655
# num_of_inputs:  656
# num_of_inputs:  657
# num_of_inputs:  658
# num_of_inputs:  659
# num_of_inputs:  660
# num_of_inputs:  661
# num_of_inputs:  662
# num_of_inputs:  663
# num_of_inputs:  664
# num_of_inputs:  665
# num_of_inputs:  666
# num_of_inputs:  667
# num_of_inputs:  668
# num_of_inputs:  669
# num_of_inputs:  670
# num_of_inputs:  671
# num_of_inputs:  672
# num_of_inputs:  673
# num_of_inputs:  674
# num_of_inputs:  675
# num_of_inputs:  676
# num_of_inputs:  677
# num_of_inputs:  678
# num_of_inputs:  679
# num_of_inputs:  680
# num_of_inputs:  681
# num_of_inputs:  682
# num_of_inputs:  683
# num_of_inputs:  684
# num_of_inputs:  685
# num_of_inputs:  686
# num_of_inputs:  687
# num_of_inputs:  688
# num_of_inputs:  689
# num_of_inputs:  690
# num_of_inputs:  691
# num_of_inputs:  692
# num_of_inputs:  693
# num_of_inputs:  694
# num_of_inputs:  695
# num_of_inputs:  696
# num_of_inputs:  697
# num_of_inputs:  698
# num_of_inputs:  699
# num_of_inputs:  700
# num_of_inputs:  701
# num_of_inputs:  702
# num_of_inputs:  703
# num_of_inputs:  704
# num_of_inputs:  705
# num_of_inputs:  706
# num_of_inputs:  707
# num_of_inputs:  708
# num_of_inputs:  709
# num_of_inputs:  710
# num_of_inputs:  711
# num_of_inputs:  712
# num_of_inputs:  713
# num_of_inputs:  714
# num_of_inputs:  715
# num_of_inputs:  716
# num_of_inputs:  717
# num_of_inputs:  718
# num_of_inputs:  719
# num_of_inputs:  720
# num_of_inputs:  721
# num_of_inputs:  722
# num_of_inputs:  723
# num_of_inputs:  724
# num_of_inputs:  725
# num_of_inputs:  726
# num_of_inputs:  727
# num_of_inputs:  728
# num_of_inputs:  729
# num_of_inputs:  730
# num_of_inputs:  731
# num_of_inputs:  732
# num_of_inputs:  733
# num_of_inputs:  734
# num_of_inputs:  735
# num_of_inputs:  736
# num_of_inputs:  737
# num_of_inputs:  738
# num_of_inputs:  739
# num_of_inputs:  740
# num_of_inputs:  741
# num_of_inputs:  742
# num_of_inputs:  743
# num_of_inputs:  744
# num_of_inputs:  745
# num_of_inputs:  746
# num_of_inputs:  747
# num_of_inputs:  748
# num_of_inputs:  749
# num_of_inputs:  750
# num_of_inputs:  751
# num_of_inputs:  752
# num_of_inputs:  753
# num_of_inputs:  754
# num_of_inputs:  755
# num_of_inputs:  756
# num_of_inputs:  757
# num_of_inputs:  758
# num_of_inputs:  759
# num_of_inputs:  760
# num_of_inputs:  761
# num_of_inputs:  762
# num_of_inputs:  763
# num_of_inputs:  764
# num_of_inputs:  765
# num_of_inputs:  766
# num_of_inputs:  767
# num_of_inputs:  768
# num_of_inputs:  769
# num_of_inputs:  770
# num_of_inputs:  771
# num_of_inputs:  772
# num_of_inputs:  773
# num_of_inputs:  774
# num_of_inputs:  775
# num_of_inputs:  776
# num_of_inputs:  777
# num_of_inputs:  778
# num_of_inputs:  779
# num_of_inputs:  780
# num_of_inputs:  781
# num_of_inputs:  782
# num_of_inputs:  783
# num_of_inputs:  784
# num_of_inputs:  785
# num_of_inputs:  786
# num_of_inputs:  787
# num_of_inputs:  788
# num_of_inputs:  789
# num_of_inputs:  790
# num_of_inputs:  791
# num_of_inputs:  792
# num_of_inputs:  793
# num_of_inputs:  794
# num_of_inputs:  795
# num_of_inputs:  796
# num_of_inputs:  797
# num_of_inputs:  798
# num_of_inputs:  799
# num_of_inputs:  800
# num_of_inputs:  801
# num_of_inputs:  802
# num_of_inputs:  803
# num_of_inputs:  804
# num_of_inputs:  805
# num_of_inputs:  806
# num_of_inputs:  807
# num_of_inputs:  808
# num_of_inputs:  809
# num_of_inputs:  810
# num_of_inputs:  811
# num_of_inputs:  812
# num_of_inputs:  813
# num_of_inputs:  814
# num_of_inputs:  815
# num_of_inputs:  816
# num_of_inputs:  817
# num_of_inputs:  818
# num_of_inputs:  819
# num_of_inputs:  820
# num_of_inputs:  821
# num_of_inputs:  822
# num_of_inputs:  823
# num_of_inputs:  824
# num_of_inputs:  825
# num_of_inputs:  826
# num_of_inputs:  827
# num_of_inputs:  828
# num_of_inputs:  829
# num_of_inputs:  830
# num_of_inputs:  831
# num_of_inputs:  832
# num_of_inputs:  833
# num_of_inputs:  834
# num_of_inputs:  835
# num_of_inputs:  836
# num_of_inputs:  837
# num_of_inputs:  838
# num_of_inputs:  839
# num_of_inputs:  840
# num_of_inputs:  841
# num_of_inputs:  842
# num_of_inputs:  843
# num_of_inputs:  844
# num_of_inputs:  845
# num_of_inputs:  846
# num_of_inputs:  847
# num_of_inputs:  848
# num_of_inputs:  849
# num_of_inputs:  850
# num_of_inputs:  851
# num_of_inputs:  852
# num_of_inputs:  853
# num_of_inputs:  854
# num_of_inputs:  855
# num_of_inputs:  856
# num_of_inputs:  857
# num_of_inputs:  858
# num_of_inputs:  859
# num_of_inputs:  860
# num_of_inputs:  861
# num_of_inputs:  862
# num_of_inputs:  863
# num_of_inputs:  864
# num_of_inputs:  865
# num_of_inputs:  866
# num_of_inputs:  867
# num_of_inputs:  868
# num_of_inputs:  869
# num_of_inputs:  870
# num_of_inputs:  871
# num_of_inputs:  872
# num_of_inputs:  873
# num_of_inputs:  874
# num_of_inputs:  875
# num_of_inputs:  876
# num_of_inputs:  877
# num_of_inputs:  878
# num_of_inputs:  879
# num_of_inputs:  880
# num_of_inputs:  881
# num_of_inputs:  882
# num_of_inputs:  883
# num_of_inputs:  884
# num_of_inputs:  885
# num_of_inputs:  886
# num_of_inputs:  887
# num_of_inputs:  888
# num_of_inputs:  889
# num_of_inputs:  890
# num_of_inputs:  891
# num_of_inputs:  892
# num_of_inputs:  893
# num_of_inputs:  894
# num_of_inputs:  895
# num_of_inputs:  896
# num_of_inputs:  897
# num_of_inputs:  898
# num_of_inputs:  899
# num_of_inputs:  900
# num_of_inputs:  901
# num_of_inputs:  902
# num_of_inputs:  903
# num_of_inputs:  904
# num_of_inputs:  905
# num_of_inputs:  906
# num_of_inputs:  907
# num_of_inputs:  908
# num_of_inputs:  909
# num_of_inputs:  910
# num_of_inputs:  911
# num_of_inputs:  912
# num_of_inputs:  913
# num_of_inputs:  914
# num_of_inputs:  915
# num_of_inputs:  916
# num_of_inputs:  917
# num_of_inputs:  918
# num_of_inputs:  919
# num_of_inputs:  920
# num_of_inputs:  921
# num_of_inputs:  922
# num_of_inputs:  923
# num_of_inputs:  924
# num_of_inputs:  925
# num_of_inputs:  926
# num_of_inputs:  927
# num_of_inputs:  928
# num_of_inputs:  929
# num_of_inputs:  930
# num_of_inputs:  931
# num_of_inputs:  932
# num_of_inputs:  933
# num_of_inputs:  934
# num_of_inputs:  935
# num_of_inputs:  936
# num_of_inputs:  937
# num_of_inputs:  938
# num_of_inputs:  939
# num_of_inputs:  940
# num_of_inputs:  941
# num_of_inputs:  942
# num_of_inputs:  943
# num_of_inputs:  944
# num_of_inputs:  945
# num_of_inputs:  946
# num_of_inputs:  947
# num_of_inputs:  948
# num_of_inputs:  949
# num_of_inputs:  950
# num_of_inputs:  951
# num_of_inputs:  952
# num_of_inputs:  953
# num_of_inputs:  954
# num_of_inputs:  955
# num_of_inputs:  956
# num_of_inputs:  957
# num_of_inputs:  958
# num_of_inputs:  959
# num_of_inputs:  960
# num_of_inputs:  961
# num_of_inputs:  962
# num_of_inputs:  963
# num_of_inputs:  964
# num_of_inputs:  965
# num_of_inputs:  966
# num_of_inputs:  967
# num_of_inputs:  968
# num_of_inputs:  969
# num_of_inputs:  970
# num_of_inputs:  971
# num_of_inputs:  972
# num_of_inputs:  973
# num_of_inputs:  974
# num_of_inputs:  975
# num_of_inputs:  976
# num_of_inputs:  977
# num_of_inputs:  978
# num_of_inputs:  979
# num_of_inputs:  980
# num_of_inputs:  981
# num_of_inputs:  982
# num_of_inputs:  983
# num_of_inputs:  984
# num_of_inputs:  985
# num_of_inputs:  986
# num_of_inputs:  987
# num_of_inputs:  988
# num_of_inputs:  989
# num_of_inputs:  990
# num_of_inputs:  991
# num_of_inputs:  992
# num_of_inputs:  993
# num_of_inputs:  994
# num_of_inputs:  995
# num_of_inputs:  996
# num_of_inputs:  997
# num_of_inputs:  998
# num_of_inputs:  999
# num_of_inputs:  1000
# num_of_inputs:  1001
# num_of_inputs:  1002
# num_of_inputs:  1003
# num_of_inputs:  1004
# num_of_inputs:  1005
# num_of_inputs:  1006
# num_of_inputs:  1007
# num_of_inputs:  1008
# num_of_inputs:  1009
# num_of_inputs:  1010
# num_of_inputs:  1011
# num_of_inputs:  1012
# num_of_inputs:  1013
# num_of_inputs:  1014
# num_of_inputs:  1015
# num_of_inputs:  1016
# num_of_inputs:  1017
# num_of_inputs:  1018
# num_of_inputs:  1019
# num_of_inputs:  1020
# num_of_inputs:  1021
# num_of_inputs:  1022
# num_of_inputs:  1023
# num_of_inputs:  1024
# num_of_inputs:  1025
# num_of_inputs:  1026
# num_of_inputs:  1027
# num_of_inputs:  1028
# num_of_inputs:  1029
# num_of_inputs:  1030
# num_of_inputs:  1031
# num_of_inputs:  1032
# num_of_inputs:  1033
# num_of_inputs:  1034
# num_of_inputs:  1035
# num_of_inputs:  1036
# num_of_inputs:  1037
# num_of_inputs:  1038
# num_of_inputs:  1039
# num_of_inputs:  1040
# num_of_inputs:  1041
# num_of_inputs:  1042
# num_of_inputs:  1043
# num_of_inputs:  1044
# num_of_inputs:  1045
# num_of_inputs:  1046
# num_of_inputs:  1047
# num_of_inputs:  1048
# num_of_inputs:  1049
# num_of_inputs:  1050
# num_of_inputs:  1051
# num_of_inputs:  1052
# num_of_inputs:  1053
# num_of_inputs:  1054
# num_of_inputs:  1055
# num_of_inputs:  1056
# num_of_inputs:  1057
# num_of_inputs:  1058
# num_of_inputs:  1059
# num_of_inputs:  1060
# num_of_inputs:  1061
# num_of_inputs:  1062
# num_of_inputs:  1063
# num_of_inputs:  1064
# num_of_inputs:  1065
# num_of_inputs:  1066
# num_of_inputs:  1067
# num_of_inputs:  1068
# num_of_inputs:  1069
# num_of_inputs:  1070
# num_of_inputs:  1071
# num_of_inputs:  1072
# num_of_inputs:  1073
# num_of_inputs:  1074
# num_of_inputs:  1075
# num_of_inputs:  1076
# num_of_inputs:  1077
# num_of_inputs:  1078
# num_of_inputs:  1079
# num_of_inputs:  1080
# num_of_inputs:  1081
# num_of_inputs:  1082
# num_of_inputs:  1083
# num_of_inputs:  1084
# num_of_inputs:  1085
# num_of_inputs:  1086
# num_of_inputs:  1087
# num_of_inputs:  1088
# num_of_inputs:  1089
# num_of_inputs:  1090
# num_of_inputs:  1091
# num_of_inputs:  1092
# num_of_inputs:  1093
# num_of_inputs:  1094
# num_of_inputs:  1095
# num_of_inputs:  1096
# num_of_inputs:  1097
# num_of_inputs:  1098
# num_of_inputs:  1099
# num_of_inputs:  1100
# num_of_inputs:  1101
# num_of_inputs:  1102
# num_of_inputs:  1103
# num_of_inputs:  1104
# num_of_inputs:  1105
# num_of_inputs:  1106
# num_of_inputs:  1107
# num_of_inputs:  1108
# num_of_inputs:  1109
# num_of_inputs:  1110
# num_of_inputs:  1111
# num_of_inputs:  1112
# num_of_inputs:  1113
# num_of_inputs:  1114
# num_of_inputs:  1115
# num_of_inputs:  1116
# num_of_inputs:  1117
# num_of_inputs:  1118
# num_of_inputs:  1119
# num_of_inputs:  1120
# num_of_inputs:  1121
# num_of_inputs:  1122
# num_of_inputs:  1123
# num_of_inputs:  1124
# num_of_inputs:  1125
# num_of_inputs:  1126
# num_of_inputs:  1127
# num_of_inputs:  1128
# num_of_inputs:  1129
# num_of_inputs:  1130
# num_of_inputs:  1131
# num_of_inputs:  1132
# num_of_inputs:  1133
# num_of_inputs:  1134
# num_of_inputs:  1135
# num_of_inputs:  1136
# num_of_inputs:  1137
# num_of_inputs:  1138
# num_of_inputs:  1139
# num_of_inputs:  1140
# num_of_inputs:  1141
# num_of_inputs:  1142
# num_of_inputs:  1143
# num_of_inputs:  1144
# num_of_inputs:  1145
# num_of_inputs:  1146
# num_of_inputs:  1147
# num_of_inputs:  1148
# num_of_inputs:  1149
# num_of_inputs:  1150
# num_of_inputs:  1151
# num_of_inputs:  1152
# num_of_inputs:  1153
# num_of_inputs:  1154
# num_of_inputs:  1155
# num_of_inputs:  1156
# num_of_inputs:  1157
# num_of_inputs:  1158
# num_of_inputs:  1159
# num_of_inputs:  1160
# num_of_inputs:  1161
# num_of_inputs:  1162
# num_of_inputs:  1163
# num_of_inputs:  1164
# num_of_inputs:  1165
# num_of_inputs:  1166
# num_of_inputs:  1167
# num_of_inputs:  1168
# num_of_inputs:  1169
# num_of_inputs:  1170
# num_of_inputs:  1171
# num_of_inputs:  1172
# num_of_inputs:  1173
# num_of_inputs:  1174
# num_of_inputs:  1175
# num_of_inputs:  1176
# num_of_inputs:  1177
# num_of_inputs:  1178
# num_of_inputs:  1179
# num_of_inputs:  1180
# num_of_inputs:  1181
# num_of_inputs:  1182
# num_of_inputs:  1183
# num_of_inputs:  1184
# num_of_inputs:  1185
# num_of_inputs:  1186
# num_of_inputs:  1187
# num_of_inputs:  1188
# num_of_inputs:  1189
# num_of_inputs:  1190
# num_of_inputs:  1191
# num_of_inputs:  1192
# num_of_inputs:  1193
# num_of_inputs:  1194
# num_of_inputs:  1195
# num_of_inputs:  1196
# num_of_inputs:  1197
# num_of_inputs:  1198
# num_of_inputs:  1199
# num_of_inputs:  1200
# num_of_inputs:  1201
# num_of_inputs:  1202
# num_of_inputs:  1203
# num_of_inputs:  1204
# num_of_inputs:  1205
# num_of_inputs:  1206
# num_of_inputs:  1207
# num_of_inputs:  1208
# num_of_inputs:  1209
# num_of_inputs:  1210
# num_of_inputs:  1211
# num_of_inputs:  1212
# num_of_inputs:  1213
# num_of_inputs:  1214
# num_of_inputs:  1215
# num_of_inputs:  1216
# num_of_inputs:  1217
# num_of_inputs:  1218
# num_of_inputs:  1219
# num_of_inputs:  1220
# num_of_inputs:  1221
# num_of_inputs:  1222
# num_of_inputs:  1223
# num_of_inputs:  1224
# num_of_inputs:  1225
# num_of_inputs:  1226
# num_of_inputs:  1227
# num_of_inputs:  1228
# num_of_inputs:  1229
# num_of_inputs:  1230
# num_of_inputs:  1231
# num_of_inputs:  1232
# num_of_inputs:  1233
# num_of_inputs:  1234
# num_of_inputs:  1235
# num_of_inputs:  1236
# num_of_inputs:  1237
# num_of_inputs:  1238
# num_of_inputs:  1239
# num_of_inputs:  1240
# num_of_inputs:  1241
# num_of_inputs:  1242
# num_of_inputs:  1243
# num_of_inputs:  1244
# num_of_inputs:  1245
# num_of_inputs:  1246
# num_of_inputs:  1247
# num_of_inputs:  1248
# num_of_inputs:  1249
# num_of_inputs:  1250
# num_of_inputs:  1251
# num_of_inputs:  1252
# num_of_inputs:  1253
# num_of_inputs:  1254
# num_of_inputs:  1255
# num_of_inputs:  1256
# num_of_inputs:  1257
# num_of_inputs:  1258
# num_of_inputs:  1259
# num_of_inputs:  1260
# num_of_inputs:  1261
# num_of_inputs:  1262
# num_of_inputs:  1263
# num_of_inputs:  1264
# num_of_inputs:  1265
# num_of_inputs:  1266
# num_of_inputs:  1267
# num_of_inputs:  1268
# num_of_inputs:  1269
# num_of_inputs:  1270
# num_of_inputs:  1271
# num_of_inputs:  1272
# num_of_inputs:  1273
# num_of_inputs:  1274
# num_of_inputs:  1275
# num_of_inputs:  1276
# num_of_inputs:  1277
# num_of_inputs:  1278
# num_of_inputs:  1279
# num_of_inputs:  1280
# num_of_inputs:  1281
# num_of_inputs:  1282
# num_of_inputs:  1283
# num_of_inputs:  1284
# num_of_inputs:  1285
# num_of_inputs:  1286
# num_of_inputs:  1287
# num_of_inputs:  1288
# num_of_inputs:  1289
# num_of_inputs:  1290
# num_of_inputs:  1291
# num_of_inputs:  1292
# num_of_inputs:  1293
# num_of_inputs:  1294
# num_of_inputs:  1295
# num_of_inputs:  1296
# num_of_inputs:  1297
# num_of_inputs:  1298
# num_of_inputs:  1299
# num_of_inputs:  1300
# num_of_inputs:  1301
# num_of_inputs:  1302
# num_of_inputs:  1303
# num_of_inputs:  1304
# num_of_inputs:  1305
# num_of_inputs:  1306
# num_of_inputs:  1307
# num_of_inputs:  1308
# num_of_inputs:  1309
# num_of_inputs:  1310
# num_of_inputs:  1311
# num_of_inputs:  1312
# num_of_inputs:  1313
# num_of_inputs:  1314
# num_of_inputs:  1315
# num_of_inputs:  1316
# num_of_inputs:  1317
# num_of_inputs:  1318
# num_of_inputs:  1319
# num_of_inputs:  1320
# num_of_inputs:  1321
# num_of_inputs:  1322
# num_of_inputs:  1323
# num_of_inputs:  1324
# num_of_inputs:  1325
# num_of_inputs:  1326
# num_of_inputs:  1327
# num_of_inputs:  1328
# num_of_inputs:  1329
# num_of_inputs:  1330
# num_of_inputs:  1331
# num_of_inputs:  1332
# num_of_inputs:  1333
# num_of_inputs:  1334
# num_of_inputs:  1335
# num_of_inputs:  1336
# num_of_inputs:  1337
# num_of_inputs:  1338
# num_of_inputs:  1339
# num_of_inputs:  1340
# num_of_inputs:  1341
# num_of_inputs:  1342
# num_of_inputs:  1343
# num_of_inputs:  1344
# num_of_inputs:  1345
# num_of_inputs:  1346
# num_of_inputs:  1347
# num_of_inputs:  1348
# num_of_inputs:  1349
# num_of_inputs:  1350
# num_of_inputs:  1351
# num_of_inputs:  1352
# num_of_inputs:  1353
# num_of_inputs:  1354
# num_of_inputs:  1355
# num_of_inputs:  1356
# num_of_inputs:  1357
# num_of_inputs:  1358
# num_of_inputs:  1359
# num_of_inputs:  1360
# num_of_inputs:  1361
# num_of_inputs:  1362
# num_of_inputs:  1363
# num_of_inputs:  1364
# num_of_inputs:  1365
# num_of_inputs:  1366
# num_of_inputs:  1367
# num_of_inputs:  1368
# num_of_inputs:  1369
# num_of_inputs:  1370
# num_of_inputs:  1371
# num_of_inputs:  1372
# num_of_inputs:  1373
# num_of_inputs:  1374
# num_of_inputs:  1375
# num_of_inputs:  1376
# num_of_inputs:  1377
# num_of_inputs:  1378
# num_of_inputs:  1379
# num_of_inputs:  1380
# num_of_inputs:  1381
# num_of_inputs:  1382
# num_of_inputs:  1383
# num_of_inputs:  1384
# num_of_inputs:  1385
# num_of_inputs:  1386
# num_of_inputs:  1387
# num_of_inputs:  1388
# num_of_inputs:  1389
# num_of_inputs:  1390
# num_of_inputs:  1391
# num_of_inputs:  1392
# num_of_inputs:  1393
# num_of_inputs:  1394
# num_of_inputs:  1395
# num_of_inputs:  1396
# num_of_inputs:  1397
# num_of_inputs:  1398
# num_of_inputs:  1399
# num_of_inputs:  1400
# num_of_inputs:  1401
# num_of_inputs:  1402
# num_of_inputs:  1403
# num_of_inputs:  1404
# num_of_inputs:  1405
# num_of_inputs:  1406
# num_of_inputs:  1407
# num_of_inputs:  1408
# num_of_inputs:  1409
# num_of_inputs:  1410
# num_of_inputs:  1411
# num_of_inputs:  1412
# num_of_inputs:  1413
# num_of_inputs:  1414
# num_of_inputs:  1415
# num_of_inputs:  1416
# num_of_inputs:  1417
# num_of_inputs:  1418
# num_of_inputs:  1419
# num_of_inputs:  1420
# num_of_inputs:  1421
# num_of_inputs:  1422
# num_of_inputs:  1423
# num_of_inputs:  1424
# num_of_inputs:  1425
# num_of_inputs:  1426
# num_of_inputs:  1427
# num_of_inputs:  1428
# num_of_inputs:  1429
# num_of_inputs:  1430
# num_of_inputs:  1431
# num_of_inputs:  1432
# num_of_inputs:  1433
# num_of_inputs:  1434
# num_of_inputs:  1435
# num_of_inputs:  1436
# num_of_inputs:  1437
# num_of_inputs:  1438
# num_of_inputs:  1439
# num_of_inputs:  1440
# num_of_inputs:  1441
# num_of_inputs:  1442
# num_of_inputs:  1443
# num_of_inputs:  1444
# num_of_inputs:  1445
# num_of_inputs:  1446
# num_of_inputs:  1447
# num_of_inputs:  1448
# num_of_inputs:  1449
# num_of_inputs:  1450
# num_of_inputs:  1451
# num_of_inputs:  1452
# num_of_inputs:  1453
# num_of_inputs:  1454
# num_of_inputs:  1455
# num_of_inputs:  1456
# num_of_inputs:  1457
# num_of_inputs:  1458
# num_of_inputs:  1459
# num_of_inputs:  1460
# num_of_inputs:  1461
# num_of_inputs:  1462
# num_of_inputs:  1463
# num_of_inputs:  1464
# num_of_inputs:  1465
# num_of_inputs:  1466
# num_of_inputs:  1467
# num_of_inputs:  1468
# num_of_inputs:  1469
# num_of_inputs:  1470
# num_of_inputs:  1471
# num_of_inputs:  1472
# num_of_inputs:  1473
# num_of_inputs:  1474
# num_of_inputs:  1475
# num_of_inputs:  1476
# num_of_inputs:  1477
# num_of_inputs:  1478
# num_of_inputs:  1479
# num_of_inputs:  1480
# num_of_inputs:  1481
# num_of_inputs:  1482
# num_of_inputs:  1483
# num_of_inputs:  1484
# num_of_inputs:  1485
# num_of_inputs:  1486
# num_of_inputs:  1487
# num_of_inputs:  1488
# num_of_inputs:  1489
# num_of_inputs:  1490
# num_of_inputs:  1491
# num_of_inputs:  1492
# num_of_inputs:  1493
# num_of_inputs:  1494
# num_of_inputs:  1495
# num_of_inputs:  1496
# num_of_inputs:  1497
# num_of_inputs:  1498
# num_of_inputs:  1499
# num_of_inputs:  1500
# num_of_inputs:  1501
# num_of_inputs:  1502
# num_of_inputs:  1503
# num_of_inputs:  1504
# num_of_inputs:  1505
# num_of_inputs:  1506
# num_of_inputs:  1507
# num_of_inputs:  1508
# num_of_inputs:  1509
# num_of_inputs:  1510
# num_of_inputs:  1511
# num_of_inputs:  1512
# num_of_inputs:  1513
# num_of_inputs:  1514
# num_of_inputs:  1515
# num_of_inputs:  1516
# num_of_inputs:  1517
# num_of_inputs:  1518
# num_of_inputs:  1519
# num_of_inputs:  1520
# num_of_inputs:  1521
# num_of_inputs:  1522
# num_of_inputs:  1523
# num_of_inputs:  1524
# num_of_inputs:  1525
# num_of_inputs:  1526
# num_of_inputs:  1527
# num_of_inputs:  1528
# num_of_inputs:  1529
# num_of_inputs:  1530
# num_of_inputs:  1531
# num_of_inputs:  1532
# num_of_inputs:  1533
# num_of_inputs:  1534
# num_of_inputs:  1535
# num_of_inputs:  1536
# num_of_inputs:  1537
# num_of_inputs:  1538
# num_of_inputs:  1539
# num_of_inputs:  1540
# num_of_inputs:  1541
# num_of_inputs:  1542
# num_of_inputs:  1543
# num_of_inputs:  1544
# num_of_inputs:  1545
# num_of_inputs:  1546
# num_of_inputs:  1547
# num_of_inputs:  1548
# num_of_inputs:  1549
# num_of_inputs:  1550
# num_of_inputs:  1551
# num_of_inputs:  1552
# num_of_inputs:  1553
# num_of_inputs:  1554
# num_of_inputs:  1555
# num_of_inputs:  1556
# num_of_inputs:  1557
# num_of_inputs:  1558
# num_of_inputs:  1559
# num_of_inputs:  1560
# num_of_inputs:  1561
# num_of_inputs:  1562
# num_of_inputs:  1563
# num_of_inputs:  1564
# num_of_inputs:  1565
# num_of_inputs:  1566
# num_of_inputs:  1567
# num_of_inputs:  1568
# num_of_inputs:  1569
# num_of_inputs:  1570
# num_of_inputs:  1571
# num_of_inputs:  1572
# num_of_inputs:  1573
# num_of_inputs:  1574
# num_of_inputs:  1575
# num_of_inputs:  1576
# num_of_inputs:  1577
# num_of_inputs:  1578
# num_of_inputs:  1579
# num_of_inputs:  1580
# num_of_inputs:  1581
# num_of_inputs:  1582
# num_of_inputs:  1583
# num_of_inputs:  1584
# num_of_inputs:  1585
# num_of_inputs:  1586
# num_of_inputs:  1587
# num_of_inputs:  1588
# num_of_inputs:  1589
# num_of_inputs:  1590
# num_of_inputs:  1591
# num_of_inputs:  1592
# num_of_inputs:  1593
# num_of_inputs:  1594
# num_of_inputs:  1595
# num_of_inputs:  1596
# num_of_inputs:  1597
# num_of_inputs:  1598
# num_of_inputs:  1599
# num_of_inputs:  1600
# num_of_inputs:  1601
# num_of_inputs:  1602
# num_of_inputs:  1603
# num_of_inputs:  1604
# num_of_inputs:  1605
# num_of_inputs:  1606
# num_of_inputs:  1607
# num_of_inputs:  1608
# num_of_inputs:  1609
# num_of_inputs:  1610
# num_of_inputs:  1611
# num_of_inputs:  1612
# num_of_inputs:  1613
# num_of_inputs:  1614
# num_of_inputs:  1615
# num_of_inputs:  1616
# num_of_inputs:  1617
# num_of_inputs:  1618
# num_of_inputs:  1619
# num_of_inputs:  1620
# num_of_inputs:  1621
# num_of_inputs:  1622
# num_of_inputs:  1623
# num_of_inputs:  1624
# num_of_inputs:  1625
# num_of_inputs:  1626
# num_of_inputs:  1627
# num_of_inputs:  1628
# num_of_inputs:  1629
# num_of_inputs:  1630
# num_of_inputs:  1631
# num_of_inputs:  1632
# num_of_inputs:  1633
# num_of_inputs:  1634
# num_of_inputs:  1635
# num_of_inputs:  1636
# num_of_inputs:  1637
# num_of_inputs:  1638
# num_of_inputs:  1639
# num_of_inputs:  1640
# num_of_inputs:  1641
# num_of_inputs:  1642
# num_of_inputs:  1643
# num_of_inputs:  1644
# num_of_inputs:  1645
# num_of_inputs:  1646
# num_of_inputs:  1647
# num_of_inputs:  1648
# num_of_inputs:  1649
# num_of_inputs:  1650
# num_of_inputs:  1651
# num_of_inputs:  1652
# num_of_inputs:  1653
# num_of_inputs:  1654
# num_of_inputs:  1655
# num_of_inputs:  1656
# num_of_inputs:  1657
# num_of_inputs:  1658
# num_of_inputs:  1659
# num_of_inputs:  1660
# num_of_inputs:  1661
# num_of_inputs:  1662
# num_of_inputs:  1663
# num_of_inputs:  1664
# num_of_inputs:  1665
# num_of_inputs:  1666
# num_of_inputs:  1667
# num_of_inputs:  1668
# num_of_inputs:  1669
# num_of_inputs:  1670
# num_of_inputs:  1671
# num_of_inputs:  1672
# num_of_inputs:  1673
# num_of_inputs:  1674
# num_of_inputs:  1675
# num_of_inputs:  1676
# num_of_inputs:  1677
# num_of_inputs:  1678
# num_of_inputs:  1679
# num_of_inputs:  1680
# num_of_inputs:  1681
# num_of_inputs:  1682
# num_of_inputs:  1683
# num_of_inputs:  1684
# num_of_inputs:  1685
# num_of_inputs:  1686
# num_of_inputs:  1687
# num_of_inputs:  1688
# num_of_inputs:  1689
# num_of_inputs:  1690
# num_of_inputs:  1691
# num_of_inputs:  1692
# num_of_inputs:  1693
# num_of_inputs:  1694
# num_of_inputs:  1695
# num_of_inputs:  1696
# num_of_inputs:  1697
# num_of_inputs:  1698
# num_of_inputs:  1699
# num_of_inputs:  1700
# num_of_inputs:  1701
# num_of_inputs:  1702
# num_of_inputs:  1703
# num_of_inputs:  1704
# num_of_inputs:  1705
# num_of_inputs:  1706
# num_of_inputs:  1707
# num_of_inputs:  1708
# num_of_inputs:  1709
# num_of_inputs:  1710
# num_of_inputs:  1711
# num_of_inputs:  1712
# num_of_inputs:  1713
# num_of_inputs:  1714
# num_of_inputs:  1715
# num_of_inputs:  1716
# num_of_inputs:  1717
# num_of_inputs:  1718
# num_of_inputs:  1719
# num_of_inputs:  1720
# num_of_inputs:  1721
# num_of_inputs:  1722
# num_of_inputs:  1723
# num_of_inputs:  1724
# num_of_inputs:  1725
# num_of_inputs:  1726
# num_of_inputs:  1727
# num_of_inputs:  1728
# num_of_inputs:  1729
# num_of_inputs:  1730
# num_of_inputs:  1731
# num_of_inputs:  1732
# num_of_inputs:  1733
# num_of_inputs:  1734
# num_of_inputs:  1735
# num_of_inputs:  1736
# num_of_inputs:  1737
# num_of_inputs:  1738
# num_of_inputs:  1739
# num_of_inputs:  1740
# num_of_inputs:  1741
# num_of_inputs:  1742
# num_of_inputs:  1743
# num_of_inputs:  1744
# num_of_inputs:  1745
# num_of_inputs:  1746
# num_of_inputs:  1747
# num_of_inputs:  1748
# num_of_inputs:  1749
# num_of_inputs:  1750
# num_of_inputs:  1751
# num_of_inputs:  1752
# num_of_inputs:  1753
# num_of_inputs:  1754
# num_of_inputs:  1755
# num_of_inputs:  1756
# num_of_inputs:  1757
# num_of_inputs:  1758
# num_of_inputs:  1759
# num_of_inputs:  1760
# num_of_inputs:  1761
# num_of_inputs:  1762
# num_of_inputs:  1763
# num_of_inputs:  1764
# num_of_inputs:  1765
# num_of_inputs:  1766
# num_of_inputs:  1767
# num_of_inputs:  1768
# num_of_inputs:  1769
# num_of_inputs:  1770
# num_of_inputs:  1771
# num_of_inputs:  1772
# num_of_inputs:  1773
# num_of_inputs:  1774
# num_of_inputs:  1775
# num_of_inputs:  1776
# num_of_inputs:  1777
# num_of_inputs:  1778
# num_of_inputs:  1779
# num_of_inputs:  1780
# num_of_inputs:  1781
# num_of_inputs:  1782
# num_of_inputs:  1783
# num_of_inputs:  1784
# num_of_inputs:  1785
# num_of_inputs:  1786
# num_of_inputs:  1787
# num_of_inputs:  1788
# num_of_inputs:  1789
# num_of_inputs:  1790
# num_of_inputs:  1791
# num_of_inputs:  1792
# num_of_inputs:  1793
# num_of_inputs:  1794
# num_of_inputs:  1795
# num_of_inputs:  1796
# num_of_inputs:  1797
# num_of_inputs:  1798
# num_of_inputs:  1799
# num_of_inputs:  1800
# num_of_inputs:  1801
# num_of_inputs:  1802
# num_of_inputs:  1803
# num_of_inputs:  1804
# num_of_inputs:  1805
# num_of_inputs:  1806
# num_of_inputs:  1807
# num_of_inputs:  1808
# num_of_inputs:  1809
# num_of_inputs:  1810
# num_of_inputs:  1811
# num_of_inputs:  1812
# num_of_inputs:  1813
# num_of_inputs:  1814
# num_of_inputs:  1815
# num_of_inputs:  1816
# num_of_inputs:  1817
# num_of_inputs:  1818
# num_of_inputs:  1819
# num_of_inputs:  1820
# num_of_inputs:  1821
# num_of_inputs:  1822
# num_of_inputs:  1823
# num_of_inputs:  1824
# num_of_inputs:  1825
# num_of_inputs:  1826
# num_of_inputs:  1827
# num_of_inputs:  1828
# num_of_inputs:  1829
# num_of_inputs:  1830
# num_of_inputs:  1831
# num_of_inputs:  1832
# num_of_inputs:  1833
# num_of_inputs:  1834
# num_of_inputs:  1835
# num_of_inputs:  1836
# num_of_inputs:  1837
# num_of_inputs:  1838
# num_of_inputs:  1839
# num_of_inputs:  1840
# num_of_inputs:  1841
# num_of_inputs:  1842
# num_of_inputs:  1843
# num_of_inputs:  1844
# num_of_inputs:  1845
# num_of_inputs:  1846
# num_of_inputs:  1847
# num_of_inputs:  1848
# num_of_inputs:  1849
# num_of_inputs:  1850
# num_of_inputs:  1851
# num_of_inputs:  1852
# num_of_inputs:  1853
# num_of_inputs:  1854
# num_of_inputs:  1855
# num_of_inputs:  1856
# num_of_inputs:  1857
# num_of_inputs:  1858
# num_of_inputs:  1859
# num_of_inputs:  1860
# num_of_inputs:  1861
# num_of_inputs:  1862
# num_of_inputs:  1863
# num_of_inputs:  1864
# num_of_inputs:  1865
# num_of_inputs:  1866
# num_of_inputs:  1867
# num_of_inputs:  1868
# num_of_inputs:  1869
# num_of_inputs:  1870
# num_of_inputs:  1871
# num_of_inputs:  1872
# num_of_inputs:  1873
# num_of_inputs:  1874
# num_of_inputs:  1875
# num_of_inputs:  1876
# num_of_inputs:  1877
# num_of_inputs:  1878
# num_of_inputs:  1879
# num_of_inputs:  1880
# num_of_inputs:  1881
# num_of_inputs:  1882
# num_of_inputs:  1883
# num_of_inputs:  1884
# num_of_inputs:  1885
# num_of_inputs:  1886
# num_of_inputs:  1887
# num_of_inputs:  1888
# num_of_inputs:  1889
# num_of_inputs:  1890
# num_of_inputs:  1891
# num_of_inputs:  1892
# num_of_inputs:  1893
# num_of_inputs:  1894
# num_of_inputs:  1895
# num_of_inputs:  1896
# num_of_inputs:  1897
# num_of_inputs:  1898
# num_of_inputs:  1899
# num_of_inputs:  1900
# num_of_inputs:  1901
# num_of_inputs:  1902
# num_of_inputs:  1903
# num_of_inputs:  1904
# num_of_inputs:  1905
# num_of_inputs:  1906
# num_of_inputs:  1907
# num_of_inputs:  1908
# num_of_inputs:  1909
# num_of_inputs:  1910
# num_of_inputs:  1911
# num_of_inputs:  1912
# num_of_inputs:  1913
# num_of_inputs:  1914
# num_of_inputs:  1915
# num_of_inputs:  1916
# num_of_inputs:  1917
# num_of_inputs:  1918
# num_of_inputs:  1919
# num_of_inputs:  1920
# num_of_inputs:  1921
# num_of_inputs:  1922
# num_of_inputs:  1923
# num_of_inputs:  1924
# num_of_inputs:  1925
# num_of_inputs:  1926
# num_of_inputs:  1927
# num_of_inputs:  1928
# num_of_inputs:  1929
# num_of_inputs:  1930
# num_of_inputs:  1931
# num_of_inputs:  1932
# num_of_inputs:  1933
# num_of_inputs:  1934
# num_of_inputs:  1935
# num_of_inputs:  1936
# num_of_inputs:  1937
# num_of_inputs:  1938
# num_of_inputs:  1939
# num_of_inputs:  1940
# num_of_inputs:  1941
# num_of_inputs:  1942
# num_of_inputs:  1943
# num_of_inputs:  1944
# num_of_inputs:  1945
# num_of_inputs:  1946
# num_of_inputs:  1947
# num_of_inputs:  1948
# num_of_inputs:  1949
# num_of_inputs:  1950
# num_of_inputs:  1951
# num_of_inputs:  1952
# num_of_inputs:  1953
# num_of_inputs:  1954
# num_of_inputs:  1955
# num_of_inputs:  1956
# num_of_inputs:  1957
# num_of_inputs:  1958
# num_of_inputs:  1959
# num_of_inputs:  1960
# num_of_inputs:  1961
# num_of_inputs:  1962
# num_of_inputs:  1963
# num_of_inputs:  1964
# num_of_inputs:  1965
# num_of_inputs:  1966
# num_of_inputs:  1967
# num_of_inputs:  1968
# num_of_inputs:  1969
# num_of_inputs:  1970
# num_of_inputs:  1971
# num_of_inputs:  1972
# num_of_inputs:  1973
# num_of_inputs:  1974
# num_of_inputs:  1975
# num_of_inputs:  1976
# num_of_inputs:  1977
# num_of_inputs:  1978
# num_of_inputs:  1979
# num_of_inputs:  1980
# num_of_inputs:  1981
# num_of_inputs:  1982
# num_of_inputs:  1983
# num_of_inputs:  1984
# num_of_inputs:  1985
# num_of_inputs:  1986
# num_of_inputs:  1987
# num_of_inputs:  1988
# num_of_inputs:  1989
# num_of_inputs:  1990
# num_of_inputs:  1991
# num_of_inputs:  1992
# num_of_inputs:  1993
# num_of_inputs:  1994
# num_of_inputs:  1995
# num_of_inputs:  1996
# num_of_inputs:  1997
# num_of_inputs:  1998
# num_of_inputs:  1999
# num_of_inputs:  2000
# num_of_inputs:  2001
# num_of_inputs:  2002
# num_of_inputs:  2003
# num_of_inputs:  2004
# num_of_inputs:  2005
# num_of_inputs:  2006
# num_of_inputs:  2007
# num_of_inputs:  2008
# num_of_inputs:  2009
# num_of_inputs:  2010
# num_of_inputs:  2011
# num_of_inputs:  2012
# num_of_inputs:  2013
# num_of_inputs:  2014
# num_of_inputs:  2015
# num_of_inputs:  2016
# num_of_inputs:  2017
# num_of_inputs:  2018
# num_of_inputs:  2019
# num_of_inputs:  2020
# num_of_inputs:  2021
# num_of_inputs:  2022
# num_of_inputs:  2023
# num_of_inputs:  2024
# num_of_inputs:  2025
# num_of_inputs:  2026
# num_of_inputs:  2027
# num_of_inputs:  2028
# num_of_inputs:  2029
# num_of_inputs:  2030
# num_of_inputs:  2031
# num_of_inputs:  2032
# num_of_inputs:  2033
# num_of_inputs:  2034
# num_of_inputs:  2035
# num_of_inputs:  2036
# num_of_inputs:  2037
# num_of_inputs:  2038
# num_of_inputs:  2039
# num_of_inputs:  2040
# num_of_inputs:  2041
# num_of_inputs:  2042
# num_of_inputs:  2043
# num_of_inputs:  2044
# num_of_inputs:  2045
# num_of_inputs:  2046
# num_of_inputs:  2047
# num_of_inputs:  2048
# num_of_inputs:  2049
# num_of_inputs:  2050
# num_of_inputs:  2051
# num_of_inputs:  2052
# num_of_inputs:  2053
# num_of_inputs:  2054
# num_of_inputs:  2055
# num_of_inputs:  2056
# num_of_inputs:  2057
# num_of_inputs:  2058
# num_of_inputs:  2059
# num_of_inputs:  2060
# num_of_inputs:  2061
# num_of_inputs:  2062
# num_of_inputs:  2063
# num_of_inputs:  2064
# num_of_inputs:  2065
# num_of_inputs:  2066
# num_of_inputs:  2067
# num_of_inputs:  2068
# num_of_inputs:  2069
# num_of_inputs:  2070
# num_of_inputs:  2071
# num_of_inputs:  2072
# num_of_inputs:  2073
# num_of_inputs:  2074
# num_of_inputs:  2075
# num_of_inputs:  2076
# num_of_inputs:  2077
# num_of_inputs:  2078
# num_of_inputs:  2079
# num_of_inputs:  2080
# num_of_inputs:  2081
# num_of_inputs:  2082
# num_of_inputs:  2083
# num_of_inputs:  2084
# num_of_inputs:  2085
# num_of_inputs:  2086
# num_of_inputs:  2087
# num_of_inputs:  2088
# num_of_inputs:  2089
# num_of_inputs:  2090
# num_of_inputs:  2091
# num_of_inputs:  2092
# num_of_inputs:  2093
# num_of_inputs:  2094
# num_of_inputs:  2095
# num_of_inputs:  2096
# num_of_inputs:  2097
# num_of_inputs:  2098
# num_of_inputs:  2099
# num_of_inputs:  2100
# num_of_inputs:  2101
# num_of_inputs:  2102
# num_of_inputs:  2103
# num_of_inputs:  2104
# num_of_inputs:  2105
# num_of_inputs:  2106
# num_of_inputs:  2107
# num_of_inputs:  2108
# num_of_inputs:  2109
# num_of_inputs:  2110
# num_of_inputs:  2111
# num_of_inputs:  2112
# num_of_inputs:  2113
# num_of_inputs:  2114
# num_of_inputs:  2115
# num_of_inputs:  2116
# num_of_inputs:  2117
# num_of_inputs:  2118
# num_of_inputs:  2119
# num_of_inputs:  2120
# num_of_inputs:  2121
# num_of_inputs:  2122
# num_of_inputs:  2123
# num_of_inputs:  2124
# num_of_inputs:  2125
# num_of_inputs:  2126
# num_of_inputs:  2127
# num_of_inputs:  2128
# num_of_inputs:  2129
# num_of_inputs:  2130
# num_of_inputs:  2131
# num_of_inputs:  2132
# num_of_inputs:  2133
# num_of_inputs:  2134
# num_of_inputs:  2135
# num_of_inputs:  2136
# num_of_inputs:  2137
# num_of_inputs:  2138
# num_of_inputs:  2139
# num_of_inputs:  2140
# num_of_inputs:  2141
# num_of_inputs:  2142
# num_of_inputs:  2143
# num_of_inputs:  2144
# num_of_inputs:  2145
# num_of_inputs:  2146
# num_of_inputs:  2147
# num_of_inputs:  2148
# num_of_inputs:  2149
# num_of_inputs:  2150
# num_of_inputs:  2151
# num_of_inputs:  2152
# num_of_inputs:  2153
# num_of_inputs:  2154
# num_of_inputs:  2155
# num_of_inputs:  2156
# num_of_inputs:  2157
# num_of_inputs:  2158
# num_of_inputs:  2159
# num_of_inputs:  2160
# num_of_inputs:  2161
# num_of_inputs:  2162
# num_of_inputs:  2163
# num_of_inputs:  2164
# num_of_inputs:  2165
# num_of_inputs:  2166
# num_of_inputs:  2167
# num_of_inputs:  2168
# num_of_inputs:  2169
# num_of_inputs:  2170
# num_of_inputs:  2171
# num_of_inputs:  2172
# num_of_inputs:  2173
# num_of_inputs:  2174
# num_of_inputs:  2175
# num_of_inputs:  2176
# num_of_inputs:  2177
# num_of_inputs:  2178
# num_of_inputs:  2179
# num_of_inputs:  2180
# num_of_inputs:  2181
# num_of_inputs:  2182
# num_of_inputs:  2183
# num_of_inputs:  2184
# num_of_inputs:  2185
# num_of_inputs:  2186
# num_of_inputs:  2187
# num_of_inputs:  2188
# num_of_inputs:  2189
# num_of_inputs:  2190
# num_of_inputs:  2191
# num_of_inputs:  2192
# num_of_inputs:  2193
# num_of_inputs:  2194
# num_of_inputs:  2195
# num_of_inputs:  2196
# num_of_inputs:  2197
# num_of_inputs:  2198
# num_of_inputs:  2199
# num_of_inputs:  2200
# num_of_inputs:  2201
# num_of_inputs:  2202
# num_of_inputs:  2203
# num_of_inputs:  2204
# num_of_inputs:  2205
# num_of_inputs:  2206
# num_of_inputs:  2207
# num_of_inputs:  2208
# num_of_inputs:  2209
# num_of_inputs:  2210
# num_of_inputs:  2211
# num_of_inputs:  2212
# num_of_inputs:  2213
# num_of_inputs:  2214
# num_of_inputs:  2215
# num_of_inputs:  2216
# num_of_inputs:  2217
# num_of_inputs:  2218
# num_of_inputs:  2219
# num_of_inputs:  2220
# num_of_inputs:  2221
# num_of_inputs:  2222
# num_of_inputs:  2223
# num_of_inputs:  2224
# num_of_inputs:  2225
# num_of_inputs:  2226
# num_of_inputs:  2227
# num_of_inputs:  2228
# num_of_inputs:  2229
# num_of_inputs:  2230
# num_of_inputs:  2231
# num_of_inputs:  2232
# num_of_inputs:  2233
# num_of_inputs:  2234
# num_of_inputs:  2235
# num_of_inputs:  2236
# num_of_inputs:  2237
# num_of_inputs:  2238
# num_of_inputs:  2239
# num_of_inputs:  2240
# num_of_inputs:  2241
# num_of_inputs:  2242
# num_of_inputs:  2243
# num_of_inputs:  2244
# num_of_inputs:  2245
# num_of_inputs:  2246
# num_of_inputs:  2247
# num_of_inputs:  2248
# num_of_inputs:  2249
# num_of_inputs:  2250
# num_of_inputs:  2251
# num_of_inputs:  2252
# num_of_inputs:  2253
# num_of_inputs:  2254
# num_of_inputs:  2255
# num_of_inputs:  2256
# num_of_inputs:  2257
# num_of_inputs:  2258
# num_of_inputs:  2259
# num_of_inputs:  2260
# num_of_inputs:  2261
# num_of_inputs:  2262
# num_of_inputs:  2263
# num_of_inputs:  2264
# num_of_inputs:  2265
# num_of_inputs:  2266
# num_of_inputs:  2267
# num_of_inputs:  2268
# num_of_inputs:  2269
# num_of_inputs:  2270
# num_of_inputs:  2271
# num_of_inputs:  2272
# num_of_inputs:  2273
# num_of_inputs:  2274
# num_of_inputs:  2275
# num_of_inputs:  2276
# num_of_inputs:  2277
# num_of_inputs:  2278
# num_of_inputs:  2279
# num_of_inputs:  2280
# num_of_inputs:  2281
# num_of_inputs:  2282
# num_of_inputs:  2283
# num_of_inputs:  2284
# num_of_inputs:  2285
# num_of_inputs:  2286
# num_of_inputs:  2287
# num_of_inputs:  2288
# num_of_inputs:  2289
# num_of_inputs:  2290
# num_of_inputs:  2291
# num_of_inputs:  2292
# num_of_inputs:  2293
# num_of_inputs:  2294
# num_of_inputs:  2295
# num_of_inputs:  2296
# num_of_inputs:  2297
# num_of_inputs:  2298
# num_of_inputs:  2299
# num_of_inputs:  2300
# num_of_inputs:  2301
# num_of_inputs:  2302
# num_of_inputs:  2303
# num_of_inputs:  2304
# num_of_inputs:  2305
# num_of_inputs:  2306
# num_of_inputs:  2307
# num_of_inputs:  2308
# num_of_inputs:  2309
# num_of_inputs:  2310
# num_of_inputs:  2311
# num_of_inputs:  2312
# num_of_inputs:  2313
# num_of_inputs:  2314
# num_of_inputs:  2315
# num_of_inputs:  2316
# num_of_inputs:  2317
# num_of_inputs:  2318
# num_of_inputs:  2319
# num_of_inputs:  2320
# num_of_inputs:  2321
# num_of_inputs:  2322
# num_of_inputs:  2323
# num_of_inputs:  2324
# num_of_inputs:  2325
# num_of_inputs:  2326
# num_of_inputs:  2327
# num_of_inputs:  2328
# num_of_inputs:  2329
# num_of_inputs:  2330
# num_of_inputs:  2331
# num_of_inputs:  2332
# num_of_inputs:  2333
# ...
# num_of_inputs:  9239
# num_of_inputs:  9240
# num_of_inputs:  9241
# num_of_inputs:  9242
# num_of_inputs:  9243
# num_of_inputs:  9244
# num_of_inputs:  9245
# num_of_inputs:  9246
# num_of_inputs:  9247
# num_of_inputs:  9248
# num_of_inputs:  9249
# num_of_inputs:  9250
# num_of_inputs:  9251
# num_of_inputs:  9252
# num_of_inputs:  9253
# num_of_inputs:  9254
# num_of_inputs:  9255
# num_of_inputs:  9256
# num_of_inputs:  9257
# num_of_inputs:  9258
# num_of_inputs:  9259
# num_of_inputs:  9260
# num_of_inputs:  9261
# num_of_inputs:  9262
# num_of_inputs:  9263
# num_of_inputs:  9264
# num_of_inputs:  9265
# num_of_inputs:  9266
# num_of_inputs:  9267
# num_of_inputs:  9268
# num_of_inputs:  9269
# num_of_inputs:  9270
# num_of_inputs:  9271
# num_of_inputs:  9272
# num_of_inputs:  9273
# num_of_inputs:  9274
# num_of_inputs:  9275
# num_of_inputs:  9276
# num_of_inputs:  9277
# num_of_inputs:  9278
# num_of_inputs:  9279
# num_of_inputs:  9280
# num_of_inputs:  9281
# num_of_inputs:  9282
# num_of_inputs:  9283
# num_of_inputs:  9284
# num_of_inputs:  9285
# num_of_inputs:  9286
# num_of_inputs:  9287
# num_of_inputs:  9288
# num_of_inputs:  9289
# num_of_inputs:  9290
# num_of_inputs:  9291
# num_of_inputs:  9292
# num_of_inputs:  9293
# num_of_inputs:  9294
# num_of_inputs:  9295
# num_of_inputs:  9296
# num_of_inputs:  9297
# num_of_inputs:  9298
# num_of_inputs:  9299
# num_of_inputs:  9300
# num_of_inputs:  9301
# num_of_inputs:  9302
# num_of_inputs:  9303
# num_of_inputs:  9304
# num_of_inputs:  9305
# num_of_inputs:  9306
# num_of_inputs:  9307
# num_of_inputs:  9308
# num_of_inputs:  9309
# num_of_inputs:  9310
# num_of_inputs:  9311
# num_of_inputs:  9312
# num_of_inputs:  9313
# num_of_inputs:  9314
# num_of_inputs:  9315
# num_of_inputs:  9316
# num_of_inputs:  9317
# num_of_inputs:  9318
# num_of_inputs:  9319
# num_of_inputs:  9320
# num_of_inputs:  9321
# num_of_inputs:  9322
# num_of_inputs:  9323
# num_of_inputs:  9324
# num_of_inputs:  9325
# num_of_inputs:  9326
# num_of_inputs:  9327
# num_of_inputs:  9328
# num_of_inputs:  9329
# num_of_inputs:  9330
# num_of_inputs:  9331
# num_of_inputs:  9332
# num_of_inputs:  9333
# num_of_inputs:  9334
# num_of_inputs:  9335
# num_of_inputs:  9336
# num_of_inputs:  9337
# num_of_inputs:  9338
# num_of_inputs:  9339
# num_of_inputs:  9340
# num_of_inputs:  9341
# num_of_inputs:  9342
# num_of_inputs:  9343
# num_of_inputs:  9344
# num_of_inputs:  9345
# num_of_inputs:  9346
# num_of_inputs:  9347
# num_of_inputs:  9348
# num_of_inputs:  9349
# num_of_inputs:  9350
# num_of_inputs:  9351
# num_of_inputs:  9352
# num_of_inputs:  9353
# num_of_inputs:  9354
# num_of_inputs:  9355
# num_of_inputs:  9356
# num_of_inputs:  9357
# num_of_inputs:  9358
# num_of_inputs:  9359
# num_of_inputs:  9360
# num_of_inputs:  9361
# num_of_inputs:  9362
# num_of_inputs:  9363
# num_of_inputs:  9364
# num_of_inputs:  9365
# num_of_inputs:  9366
# num_of_inputs:  9367
# num_of_inputs:  9368
# num_of_inputs:  9369
# num_of_inputs:  9370
# num_of_inputs:  9371
# num_of_inputs:  9372
# num_of_inputs:  9373
# num_of_inputs:  9374
# num_of_inputs:  9375
# num_of_inputs:  9376
# num_of_inputs:  9377
# num_of_inputs:  9378
# num_of_inputs:  9379
# num_of_inputs:  9380
# num_of_inputs:  9381
# num_of_inputs:  9382
# num_of_inputs:  9383
# num_of_inputs:  9384
# num_of_inputs:  9385
# num_of_inputs:  9386
# num_of_inputs:  9387
# num_of_inputs:  9388
# num_of_inputs:  9389
# num_of_inputs:  9390
# num_of_inputs:  9391
# num_of_inputs:  9392
# num_of_inputs:  9393
# num_of_inputs:  9394
# num_of_inputs:  9395
# num_of_inputs:  9396
# num_of_inputs:  9397
# num_of_inputs:  9398
# num_of_inputs:  9399
# num_of_inputs:  9400
# num_of_inputs:  9401
# num_of_inputs:  9402
# num_of_inputs:  9403
# num_of_inputs:  9404
# num_of_inputs:  9405
# num_of_inputs:  9406
# num_of_inputs:  9407
# num_of_inputs:  9408
# num_of_inputs:  9409
# num_of_inputs:  9410
# num_of_inputs:  9411
# num_of_inputs:  9412
# num_of_inputs:  9413
# num_of_inputs:  9414
# num_of_inputs:  9415
# num_of_inputs:  9416
# num_of_inputs:  9417
# num_of_inputs:  9418
# num_of_inputs:  9419
# num_of_inputs:  9420
# num_of_inputs:  9421
# num_of_inputs:  9422
# num_of_inputs:  9423
# num_of_inputs:  9424
# num_of_inputs:  9425
# num_of_inputs:  9426
# num_of_inputs:  9427
# num_of_inputs:  9428
# num_of_inputs:  9429
# num_of_inputs:  9430
# num_of_inputs:  9431
# num_of_inputs:  9432
# num_of_inputs:  9433
# num_of_inputs:  9434
# num_of_inputs:  9435
# num_of_inputs:  9436
# num_of_inputs:  9437
# num_of_inputs:  9438
# num_of_inputs:  9439
# num_of_inputs:  9440
# num_of_inputs:  9441
# num_of_inputs:  9442
# num_of_inputs:  9443
# num_of_inputs:  9444
# num_of_inputs:  9445
# num_of_inputs:  9446
# num_of_inputs:  9447
# num_of_inputs:  9448
# num_of_inputs:  9449
# num_of_inputs:  9450
# num_of_inputs:  9451
# num_of_inputs:  9452
# num_of_inputs:  9453
# num_of_inputs:  9454
# num_of_inputs:  9455
# num_of_inputs:  9456
# num_of_inputs:  9457
# num_of_inputs:  9458
# num_of_inputs:  9459
# num_of_inputs:  9460
# num_of_inputs:  9461
# num_of_inputs:  9462
# num_of_inputs:  9463
# num_of_inputs:  9464
# num_of_inputs:  9465
# num_of_inputs:  9466
# num_of_inputs:  9467
# num_of_inputs:  9468
# num_of_inputs:  9469
# num_of_inputs:  9470
# num_of_inputs:  9471
# num_of_inputs:  9472
# num_of_inputs:  9473
# num_of_inputs:  9474
# num_of_inputs:  9475
# num_of_inputs:  9476
# num_of_inputs:  9477
# num_of_inputs:  9478
# num_of_inputs:  9479
# num_of_inputs:  9480
# num_of_inputs:  9481
# num_of_inputs:  9482
# num_of_inputs:  9483
# num_of_inputs:  9484
# num_of_inputs:  9485
# num_of_inputs:  9486
# num_of_inputs:  9487
# num_of_inputs:  9488
# num_of_inputs:  9489
# num_of_inputs:  9490
# num_of_inputs:  9491
# num_of_inputs:  9492
# num_of_inputs:  9493
# num_of_inputs:  9494
# num_of_inputs:  9495
# num_of_inputs:  9496
# num_of_inputs:  9497
# num_of_inputs:  9498
# num_of_inputs:  9499
# num_of_inputs:  9500
# num_of_inputs:  9501
# num_of_inputs:  9502
# num_of_inputs:  9503
# num_of_inputs:  9504
# num_of_inputs:  9505
# num_of_inputs:  9506
# num_of_inputs:  9507
# num_of_inputs:  9508
# num_of_inputs:  9509
# num_of_inputs:  9510
# num_of_inputs:  9511
# num_of_inputs:  9512
# num_of_inputs:  9513
# num_of_inputs:  9514
# num_of_inputs:  9515
# num_of_inputs:  9516
# num_of_inputs:  9517
# num_of_inputs:  9518
# num_of_inputs:  9519
# num_of_inputs:  9520
# num_of_inputs:  9521
# num_of_inputs:  9522
# num_of_inputs:  9523
# num_of_inputs:  9524
# num_of_inputs:  9525
# num_of_inputs:  9526
# num_of_inputs:  9527
# num_of_inputs:  9528
# num_of_inputs:  9529
# num_of_inputs:  9530
# num_of_inputs:  9531
# num_of_inputs:  9532
# num_of_inputs:  9533
# num_of_inputs:  9534
# num_of_inputs:  9535
# num_of_inputs:  9536
# num_of_inputs:  9537
# num_of_inputs:  9538
# num_of_inputs:  9539
# num_of_inputs:  9540
# num_of_inputs:  9541
# num_of_inputs:  9542
# num_of_inputs:  9543
# num_of_inputs:  9544
# num_of_inputs:  9545
# num_of_inputs:  9546
# num_of_inputs:  9547
# num_of_inputs:  9548
# num_of_inputs:  9549
# num_of_inputs:  9550
# num_of_inputs:  9551
# num_of_inputs:  9552
# num_of_inputs:  9553
# num_of_inputs:  9554
# num_of_inputs:  9555
# num_of_inputs:  9556
# num_of_inputs:  9557
# num_of_inputs:  9558
# num_of_inputs:  9559
# num_of_inputs:  9560
# num_of_inputs:  9561
# num_of_inputs:  9562
# num_of_inputs:  9563
# num_of_inputs:  9564
# num_of_inputs:  9565
# num_of_inputs:  9566
# num_of_inputs:  9567
# num_of_inputs:  9568
# num_of_inputs:  9569
# num_of_inputs:  9570
# num_of_inputs:  9571
# num_of_inputs:  9572
# num_of_inputs:  9573
# num_of_inputs:  9574
# num_of_inputs:  9575
# num_of_inputs:  9576
# num_of_inputs:  9577
# num_of_inputs:  9578
# num_of_inputs:  9579
# num_of_inputs:  9580
# num_of_inputs:  9581
# num_of_inputs:  9582
# num_of_inputs:  9583
# num_of_inputs:  9584
# num_of_inputs:  9585
# num_of_inputs:  9586
# num_of_inputs:  9587
# num_of_inputs:  9588
# num_of_inputs:  9589
# num_of_inputs:  9590
# num_of_inputs:  9591
# num_of_inputs:  9592
# num_of_inputs:  9593
# num_of_inputs:  9594
# num_of_inputs:  9595
# num_of_inputs:  9596
# num_of_inputs:  9597
# num_of_inputs:  9598
# num_of_inputs:  9599
# num_of_inputs:  9600
# num_of_inputs:  9601
# num_of_inputs:  9602
# num_of_inputs:  9603
# num_of_inputs:  9604
# num_of_inputs:  9605
# num_of_inputs:  9606
# num_of_inputs:  9607
# num_of_inputs:  9608
# num_of_inputs:  9609
# num_of_inputs:  9610
# num_of_inputs:  9611
# num_of_inputs:  9612
# num_of_inputs:  9613
# num_of_inputs:  9614
# num_of_inputs:  9615
# num_of_inputs:  9616
# num_of_inputs:  9617
# num_of_inputs:  9618
# num_of_inputs:  9619
# num_of_inputs:  9620
# num_of_inputs:  9621
# num_of_inputs:  9622
# num_of_inputs:  9623
# num_of_inputs:  9624
# num_of_inputs:  9625
# num_of_inputs:  9626
# num_of_inputs:  9627
# num_of_inputs:  9628
# num_of_inputs:  9629
# num_of_inputs:  9630
# num_of_inputs:  9631
# num_of_inputs:  9632
# num_of_inputs:  9633
# num_of_inputs:  9634
# num_of_inputs:  9635
# num_of_inputs:  9636
# num_of_inputs:  9637
# num_of_inputs:  9638
# num_of_inputs:  9639
# num_of_inputs:  9640
# num_of_inputs:  9641
# num_of_inputs:  9642
# num_of_inputs:  9643
# num_of_inputs:  9644
# num_of_inputs:  9645
# num_of_inputs:  9646
# num_of_inputs:  9647
# num_of_inputs:  9648
# num_of_inputs:  9649
# num_of_inputs:  9650
# num_of_inputs:  9651
# num_of_inputs:  9652
# num_of_inputs:  9653
# num_of_inputs:  9654
# num_of_inputs:  9655
# num_of_inputs:  9656
# num_of_inputs:  9657
# num_of_inputs:  9658
# num_of_inputs:  9659
# num_of_inputs:  9660
# num_of_inputs:  9661
# num_of_inputs:  9662
# num_of_inputs:  9663
# num_of_inputs:  9664
# num_of_inputs:  9665
# num_of_inputs:  9666
# num_of_inputs:  9667
# num_of_inputs:  9668
# num_of_inputs:  9669
# num_of_inputs:  9670
# num_of_inputs:  9671
# num_of_inputs:  9672
# num_of_inputs:  9673
# num_of_inputs:  9674
# num_of_inputs:  9675
# num_of_inputs:  9676
# num_of_inputs:  9677
# num_of_inputs:  9678
# num_of_inputs:  9679
# num_of_inputs:  9680
# num_of_inputs:  9681
# num_of_inputs:  9682
# num_of_inputs:  9683
# num_of_inputs:  9684
# num_of_inputs:  9685
# num_of_inputs:  9686
# num_of_inputs:  9687
# num_of_inputs:  9688
# num_of_inputs:  9689
# num_of_inputs:  9690
# num_of_inputs:  9691
# num_of_inputs:  9692
# num_of_inputs:  9693
# num_of_inputs:  9694
# num_of_inputs:  9695
# num_of_inputs:  9696
# num_of_inputs:  9697
# num_of_inputs:  9698
# num_of_inputs:  9699
# num_of_inputs:  9700
# num_of_inputs:  9701
# num_of_inputs:  9702
# num_of_inputs:  9703
# num_of_inputs:  9704
# num_of_inputs:  9705
# num_of_inputs:  9706
# num_of_inputs:  9707
# num_of_inputs:  9708
# num_of_inputs:  9709
# num_of_inputs:  9710
# num_of_inputs:  9711
# num_of_inputs:  9712
# num_of_inputs:  9713
# num_of_inputs:  9714
# num_of_inputs:  9715
# num_of_inputs:  9716
# num_of_inputs:  9717
# num_of_inputs:  9718
# num_of_inputs:  9719
# num_of_inputs:  9720
# num_of_inputs:  9721
# num_of_inputs:  9722
# num_of_inputs:  9723
# num_of_inputs:  9724
# num_of_inputs:  9725
# num_of_inputs:  9726
# num_of_inputs:  9727
# num_of_inputs:  9728
# num_of_inputs:  9729
# num_of_inputs:  9730
# num_of_inputs:  9731
# num_of_inputs:  9732
# num_of_inputs:  9733
# num_of_inputs:  9734
# num_of_inputs:  9735
# num_of_inputs:  9736
# num_of_inputs:  9737
# num_of_inputs:  9738
# num_of_inputs:  9739
# num_of_inputs:  9740
# num_of_inputs:  9741
# num_of_inputs:  9742
# num_of_inputs:  9743
# num_of_inputs:  9744
# num_of_inputs:  9745
# num_of_inputs:  9746
# num_of_inputs:  9747
# num_of_inputs:  9748
# num_of_inputs:  9749
# num_of_inputs:  9750
# num_of_inputs:  9751
# num_of_inputs:  9752
# num_of_inputs:  9753
# num_of_inputs:  9754
# num_of_inputs:  9755
# num_of_inputs:  9756
# num_of_inputs:  9757
# num_of_inputs:  9758
# num_of_inputs:  9759
# num_of_inputs:  9760
# num_of_inputs:  9761
# num_of_inputs:  9762
# num_of_inputs:  9763
# num_of_inputs:  9764
# num_of_inputs:  9765
# num_of_inputs:  9766
# num_of_inputs:  9767
# num_of_inputs:  9768
# num_of_inputs:  9769
# num_of_inputs:  9770
# num_of_inputs:  9771
# num_of_inputs:  9772
# num_of_inputs:  9773
# num_of_inputs:  9774
# num_of_inputs:  9775
# num_of_inputs:  9776
# num_of_inputs:  9777
# num_of_inputs:  9778
# num_of_inputs:  9779
# num_of_inputs:  9780
# num_of_inputs:  9781
# num_of_inputs:  9782
# num_of_inputs:  9783
# num_of_inputs:  9784
# num_of_inputs:  9785
# num_of_inputs:  9786
# num_of_inputs:  9787
# num_of_inputs:  9788
# num_of_inputs:  9789
# num_of_inputs:  9790
# num_of_inputs:  9791
# num_of_inputs:  9792
# num_of_inputs:  9793
# num_of_inputs:  9794
# num_of_inputs:  9795
# num_of_inputs:  9796
# num_of_inputs:  9797
# num_of_inputs:  9798
# num_of_inputs:  9799
# num_of_inputs:  9800
# num_of_inputs:  9801
# num_of_inputs:  9802
# num_of_inputs:  9803
# num_of_inputs:  9804
# num_of_inputs:  9805
# num_of_inputs:  9806
# num_of_inputs:  9807
# num_of_inputs:  9808
# num_of_inputs:  9809
# num_of_inputs:  9810
# num_of_inputs:  9811
# num_of_inputs:  9812
# num_of_inputs:  9813
# num_of_inputs:  9814
# num_of_inputs:  9815
# num_of_inputs:  9816
# num_of_inputs:  9817
# num_of_inputs:  9818
# num_of_inputs:  9819
# num_of_inputs:  9820
# num_of_inputs:  9821
# num_of_inputs:  9822
# num_of_inputs:  9823
# num_of_inputs:  9824
# num_of_inputs:  9825
# num_of_inputs:  9826
# num_of_inputs:  9827
# num_of_inputs:  9828
# num_of_inputs:  9829
# num_of_inputs:  9830
# num_of_inputs:  9831
# num_of_inputs:  9832
# num_of_inputs:  9833
# num_of_inputs:  9834
# num_of_inputs:  9835
# num_of_inputs:  9836
# num_of_inputs:  9837
# num_of_inputs:  9838
# num_of_inputs:  9839
# num_of_inputs:  9840
# num_of_inputs:  9841
# num_of_inputs:  9842
# num_of_inputs:  9843
# num_of_inputs:  9844
# num_of_inputs:  9845
# num_of_inputs:  9846
# num_of_inputs:  9847
# num_of_inputs:  9848
# num_of_inputs:  9849
# num_of_inputs:  9850
# num_of_inputs:  9851
# num_of_inputs:  9852
# num_of_inputs:  9853
# num_of_inputs:  9854
# num_of_inputs:  9855
# num_of_inputs:  9856
# num_of_inputs:  9857
# num_of_inputs:  9858
# num_of_inputs:  9859
# num_of_inputs:  9860
# num_of_inputs:  9861
# num_of_inputs:  9862
# num_of_inputs:  9863
# num_of_inputs:  9864
# num_of_inputs:  9865
# num_of_inputs:  9866
# num_of_inputs:  9867
# num_of_inputs:  9868
# num_of_inputs:  9869
# num_of_inputs:  9870
# num_of_inputs:  9871
# num_of_inputs:  9872
# num_of_inputs:  9873
# num_of_inputs:  9874
# num_of_inputs:  9875
# num_of_inputs:  9876
# num_of_inputs:  9877
# num_of_inputs:  9878
# num_of_inputs:  9879
# num_of_inputs:  9880
# num_of_inputs:  9881
# num_of_inputs:  9882
# num_of_inputs:  9883
# num_of_inputs:  9884
# num_of_inputs:  9885
# num_of_inputs:  9886
# num_of_inputs:  9887
# num_of_inputs:  9888
# num_of_inputs:  9889
# num_of_inputs:  9890
# num_of_inputs:  9891
# num_of_inputs:  9892
# num_of_inputs:  9893
# num_of_inputs:  9894
# num_of_inputs:  9895
# num_of_inputs:  9896
# num_of_inputs:  9897
# num_of_inputs:  9898
# num_of_inputs:  9899
# num_of_inputs:  9900
# num_of_inputs:  9901
# num_of_inputs:  9902
# num_of_inputs:  9903
# num_of_inputs:  9904
# num_of_inputs:  9905
# num_of_inputs:  9906
# num_of_inputs:  9907
# num_of_inputs:  9908
# num_of_inputs:  9909
# num_of_inputs:  9910
# num_of_inputs:  9911
# num_of_inputs:  9912
# num_of_inputs:  9913
# num_of_inputs:  9914
# num_of_inputs:  9915
# num_of_inputs:  9916
# num_of_inputs:  9917
# num_of_inputs:  9918
# num_of_inputs:  9919
# num_of_inputs:  9920
# num_of_inputs:  9921
# num_of_inputs:  9922
# num_of_inputs:  9923
# num_of_inputs:  9924
# num_of_inputs:  9925
# num_of_inputs:  9926
# num_of_inputs:  9927
# num_of_inputs:  9928
# num_of_inputs:  9929
# num_of_inputs:  9930
# num_of_inputs:  9931
# num_of_inputs:  9932
# num_of_inputs:  9933
# num_of_inputs:  9934
# num_of_inputs:  9935
# num_of_inputs:  9936
# num_of_inputs:  9937
# num_of_inputs:  9938
# num_of_inputs:  9939
# num_of_inputs:  9940
# num_of_inputs:  9941
# num_of_inputs:  9942
# num_of_inputs:  9943
# num_of_inputs:  9944
# num_of_inputs:  9945
# num_of_inputs:  9946
# num_of_inputs:  9947
# num_of_inputs:  9948
# num_of_inputs:  9949
# num_of_inputs:  9950
# num_of_inputs:  9951
# num_of_inputs:  9952
# num_of_inputs:  9953
# num_of_inputs:  9954
# num_of_inputs:  9955
# num_of_inputs:  9956
# num_of_inputs:  9957
# num_of_inputs:  9958
# num_of_inputs:  9959
# num_of_inputs:  9960
# num_of_inputs:  9961
# num_of_inputs:  9962
# num_of_inputs:  9963
# num_of_inputs:  9964
# num_of_inputs:  9965
# num_of_inputs:  9966
# num_of_inputs:  9967
# num_of_inputs:  9968
# num_of_inputs:  9969
# num_of_inputs:  9970
# num_of_inputs:  9971
# num_of_inputs:  9972
# num_of_inputs:  9973
# num_of_inputs:  9974
# num_of_inputs:  9975
# num_of_inputs:  9976
# num_of_inputs:  9977
# num_of_inputs:  9978
# num_of_inputs:  9979
# num_of_inputs:  9980
# num_of_inputs:  9981
# num_of_inputs:  9982
# num_of_inputs:  9983
# num_of_inputs:  9984
# num_of_inputs:  9985
# num_of_inputs:  9986
# num_of_inputs:  9987
# num_of_inputs:  9988
# num_of_inputs:  9989
# num_of_inputs:  9990
# num_of_inputs:  9991
# num_of_inputs:  9992
# num_of_inputs:  9993
# num_of_inputs:  9994
# num_of_inputs:  9995
# num_of_inputs:  9996
# num_of_inputs:  9997
# num_of_inputs:  9998
# num_of_inputs:  9999

# %%
inputs = torch.from_numpy(inputs[:num_of_inputs])

# %%
labels = torch.from_numpy(Y[:num_of_inputs])

# %%
x_train, x_test, y_train, y_test = train_test_split(inputs, labels,test_size=0.15, random_state=42)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train,test_size=0.2, random_state=42)

# %%
train_data = TensorDataset(x_train, y_train)
val_data = TensorDataset(x_val, y_val)
test_data = TensorDataset(x_test, y_test)

batch_size = 100

train_loader = DataLoader(train_data, shuffle=True, batch_size=batch_size)
val_loader = DataLoader(val_data, shuffle=True, batch_size=batch_size)
test_loader = DataLoader(test_data, shuffle=True, batch_size=batch_size)

# %%
class DosDetection(nn.Module):
    def __init__(self, input_size, output_size, hidden_dim, n_layers, drop_prob=0.5):
        super(DosDetection, self).__init__()
        self.output_size = output_size
        self.n_layers = n_layers
        self.hidden_dim = hidden_dim

        self.lstm = nn.LSTM(input_size, hidden_dim, n_layers, dropout=drop_prob, batch_first=True)
        self.dropout = nn.Dropout(drop_prob)
        self.fc = nn.Linear(hidden_dim, output_size)
        self.sigmoid = nn.Sigmoid()
        
    def forward(self, x, hidden):
        batch_size = x.size(0)
        x = x.float()
        lstm_out, hidden = self.lstm(x, hidden)
        lstm_out = lstm_out.contiguous().view(-1, self.hidden_dim)
        
        out = self.dropout(lstm_out)
        out = self.fc(out)
        out = self.sigmoid(out)
        
        out = out.view(batch_size, -1)
        out = out[:,-1]
        return out, hidden
#         return 1, 1
    
    def init_hidden(self, batch_size):
        weight = next(self.parameters()).data
        hid1 = weight.new(self.n_layers, batch_size, self.hidden_dim).zero_().to(device)
        hid2 = weight.new(self.n_layers, batch_size, self.hidden_dim).zero_().to(device)
        hidden = (hid1.float(), hid2.float())
        return hidden

# %%
input_size = 78
hidden_dim = 32
n_layers = 100
output_size = 3

model = DosDetection(input_size, output_size, hidden_dim, n_layers)
model.to(device)
print(model)
# Out:
# DosDetection(
#   (lstm): LSTM(78, 32, num_layers=100, batch_first=True, dropout=0.5)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc): Linear(in_features=32, out_features=3, bias=True)
#   (sigmoid): Sigmoid()
# )

# %%
lr=0.005
criterion = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# %%
epochs = 2
counter = 0
print_every = 1
clip = 5
valid_loss_min = np.Inf

model.train()
for i in range(epochs):
    counter = 0
    h = model.init_hidden(batch_size)
    
    for idx, (inputs, labels) in enumerate(train_loader):
        counter += 1
        h = tuple([e.data.float() for e in h])
        inputs, labels = inputs.to(device), labels.to(device)
        model.zero_grad()
        model.zero_grad()
        output, h = model(inputs, h)
        loss = criterion(output.squeeze(), labels.float())
        loss.backward()
        nn.utils.clip_grad_norm_(model.parameters(), clip)
        optimizer.step()
        
        if counter%print_every == 0:
            val_h = model.init_hidden(batch_size)
            val_losses = []
            model.eval()
            for inp, lab in val_loader:
                val_h = tuple([each.data for each in val_h])
                inp, lab = inp.to(device), lab.to(device)
                out, val_h = model(inp, val_h)
                val_loss = criterion(out.squeeze(), lab.float())
                val_losses.append(val_loss.item())
                
            model.train()
            print("Epoch: {}/{}...".format(i+1, epochs),
                  "Step: {}...".format(counter),
                  "Loss: {:.6f}...".format(loss.item()),
                  "Val Loss: {:.6f}".format(np.mean(val_losses)))
            if np.mean(val_losses) <= valid_loss_min:
                torch.save(model.state_dict(), './state_dict.pt')
                print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(valid_loss_min,np.mean(val_losses)))
                valid_loss_min = np.mean(val_losses)
# Out:
# Epoch: 1/2... Step: 1... Loss: 0.679330... Val Loss: 0.632804
# Validation loss decreased (inf --> 0.632804).  Saving model ...
# Epoch: 1/2... Step: 2... Loss: 0.631841... Val Loss: 0.588234
# Validation loss decreased (0.632804 --> 0.588234).  Saving model ...
# Epoch: 1/2... Step: 3... Loss: 0.591696... Val Loss: 0.534814
# Validation loss decreased (0.588234 --> 0.534814).  Saving model ...
# Epoch: 1/2... Step: 4... Loss: 0.537370... Val Loss: 0.459912
# Validation loss decreased (0.534814 --> 0.459912).  Saving model ...
# Epoch: 1/2... Step: 5... Loss: 0.464015... Val Loss: 0.357688
# Validation loss decreased (0.459912 --> 0.357688).  Saving model ...
# Epoch: 1/2... Step: 6... Loss: 0.368118... Val Loss: 0.259479
# Validation loss decreased (0.357688 --> 0.259479).  Saving model ...
# Epoch: 1/2... Step: 7... Loss: 0.281916... Val Loss: 0.191030
# Validation loss decreased (0.259479 --> 0.191030).  Saving model ...
# Epoch: 1/2... Step: 8... Loss: 0.204069... Val Loss: 0.144952
# Validation loss decreased (0.191030 --> 0.144952).  Saving model ...
# Epoch: 1/2... Step: 9... Loss: 0.149477... Val Loss: 0.112375
# Validation loss decreased (0.144952 --> 0.112375).  Saving model ...
